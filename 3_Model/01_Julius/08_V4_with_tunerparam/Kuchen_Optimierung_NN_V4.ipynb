# %%
# Import the necessary libraries
import pandas as pd
import keras_tuner as kt
from tensorflow.keras.layers import Dense, Dropout, InputLayer
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import (
    EarlyStopping, 
    ReduceLROnPlateau, 
    ModelCheckpoint, 
    TensorBoard,
    CSVLogger
)
import os
from datetime import datetime
import numpy as np
from sklearn.model_selection import KFold
# Import the necessary libraries



# Define the file paths
subdirectory = "pickle_data_Kuchen"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())
# Out:
# 2025-01-08 13:33:16.341034: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-08 13:33:16.366088: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736339596.396500 3440897 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736339596.405942 3440897 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 13:33:16.437157: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded Training features dimensions: (1462, 31)
# Loaded Validation features dimensions: (357, 31)
# Loaded Test features dimensions: (355, 31)
#
# Loaded Training labels dimensions: (1462, 1)
# Loaded Validation labels dimensions: (357, 1)
#
# First few rows of loaded training features:
#       Temp_Cold_current  Temp_Mild_current  Temp_Warm_current  \
# 7223                  0                  1                  0
# 7224                  0                  1                  0
# 7225                  0                  0                  1
# 7226                  0                  1                  0
# 7227                  0                  1                  0
#
#       Temp_Hot_current  Cloud_ok_current  Cloud_Cloudy_current  \
# 7223                 0                 0                     1
# 7224                 0                 1                     0
# 7225                 0                 0                     1
# 7226                 0                 0                     1
# 7227                 0                 1                     0
#
#       KielerWoche_current  Montag_current  Dienstag_current  Mittwoch_current  \
# 7223                    0               1                 0                 0
# 7224                    0               0                 1                 0
# 7225                    0               0                 0                 1
# 7226                    0               0                 0                 0
# 7227                    0               0                 0                 0
#
#       ...  Werktag_current  Sommer_current  Winter_current  \
# 7223  ...                1               1               0
# 7224  ...                1               1               0
# 7225  ...                1               1               0
# 7226  ...                1               1               0
# 7227  ...                1               1               0
#
#       wetter_sehr_schlecht_current  wetter_sehr_schön_current  \
# 7223                             0                          0
# 7224                             0                          0
# 7225                             1                          0
# 7226                             0                          0
# 7227                             0                          0
#
#       Monat_3_current  Monat_7_current  Monat_8_current  Monat_11_current  \
# 7223                0                1                0                 0
# 7224                0                1                0                 0
# 7225                0                1                0                 0
# 7226                0                1                0                 0
# 7227                0                1                0                 0
#
#       zwischen_den_jahren_current
# 7223                            0
# 7224                            0
# 7225                            0
# 7226                            0
# 7227                            0
#
# [5 rows x 31 columns]
#
# First few rows of loaded training labels:
#           Umsatz
# 7223  317.475875
# 7224  383.628682
# 7225  305.523072
# 7226  308.408168
# 7227  355.518770

# %%
class BayesianNeuralTuner:
    def __init__(
        self,
        input_shape,
        max_trials=10,
        project_name='nn_tuning',
        log_dir='logs/Kuchen',
        n_folds=3
    ):
        self.input_shape = input_shape
        self.max_trials = max_trials
        self.project_name = project_name
        self.log_dir = os.path.join(log_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
        self.n_folds = n_folds
        os.makedirs(self.log_dir, exist_ok=True)
        
    def build_model(self, hp):
        # Use factors of 2 for more efficient GPU utilization
        units1_choices = [32, 64, 96, 128]
        units2_choices = [16, 32, 48, 64]
        
        model = Sequential([
            InputLayer(shape=self.input_shape),
            
            # First dropout with tunable rate
            Dropout(hp.Float('dropout1', 0.1, 0.3, step=0.1)),
            
            # First dense layer with conditional units
            Dense(
                units=hp.Choice('units1', units1_choices),
                activation='relu',
                kernel_regularizer=l2(hp.Float(
                    'l2_reg1', 
                    1e-4, 
                    1e-2, 
                    sampling='log'
                )),
                kernel_initializer='he_normal'
            ),
            
            # Second dense layer with conditional units
            Dense(
                units=hp.Choice('units2', units2_choices),
                activation='relu',
                kernel_regularizer=l2(hp.Float(
                    'l2_reg2', 
                    1e-4, 
                    1e-2, 
                    sampling='log'
                )),
                kernel_initializer='he_normal'
            ),
            
            Dense(1)
        ])
        
        # Learning rate with warm restarts
        base_lr = hp.Float(
            'base_learning_rate',
            min_value=1e-4,
            max_value=1e-2,
            sampling='log'
        )
        
        # Optimizer with tunable parameters
        optimizer = AdamW(
            learning_rate=base_lr,
            beta_1=hp.Float('beta_1', 0.9, 0.999),
            beta_2=hp.Float('beta_2', 0.9, 0.999),
            weight_decay=hp.Float('weight_decay', 1e-4, 1e-2, sampling='log')
        )
        
        model.compile(
            optimizer=optimizer,
            loss='mse',
            metrics=['mape']
        )
        
        return model
    
    def get_callbacks(self, checkpoint_path, fold=None):
        fold_suffix = f'_fold_{fold}' if fold is not None else ''
        return [
            EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True,
                verbose=1
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=3,
                min_lr=1e-6,
                verbose=1
            ),
            ModelCheckpoint(
                filepath=checkpoint_path.format(fold=fold_suffix),
                monitor='val_loss',
                save_best_only=True,
                verbose=1
            ),
            TensorBoard(
                log_dir=os.path.join(self.log_dir, f'fold{fold_suffix}'),
                histogram_freq=1,
                write_graph=True
            ),
            CSVLogger(
                os.path.join(self.log_dir, f'training_log{fold_suffix}.csv'),
                separator=',',
                append=False
            )
        ]
    
    def cross_validate_hyperparameters(self, hp, x, y, batch_size):
        """Perform k-fold cross-validation for a set of hyperparameters"""
        kf = KFold(n_splits=self.n_folds, shuffle=True, random_state=42)
        scores = []
        
        for fold, (train_idx, val_idx) in enumerate(kf.split(x)):
            x_train_fold = x[train_idx]
            y_train_fold = y[train_idx]
            x_val_fold = x[val_idx]
            y_val_fold = y[val_idx]
            
            model = self.build_model(hp)
            checkpoint_path = os.path.join(self.log_dir, 'model_cv_{fold}.h5')
            callbacks = self.get_callbacks(checkpoint_path, fold)
            
            model.fit(
                x_train_fold,
                y_train_fold,
                epochs=100,
                batch_size=batch_size,
                validation_data=(x_val_fold, y_val_fold),
                callbacks=callbacks,
                verbose=0
            )
            
            scores.append(model.evaluate(x_val_fold, y_val_fold)[0])
        
        return np.mean(scores)
    
    def search(self, training_features, training_labels, validation_data, batch_size=24):
        checkpoint_path = os.path.join(self.log_dir, 'best_model.keras')
        
        # Initialize Bayesian Optimization tuner
        tuner = kt.BayesianOptimization(
            self.build_model,
            objective=kt.Objective('val_loss', direction='min'),
            max_trials=self.max_trials,
            directory=self.log_dir,
            project_name=self.project_name,
            overwrite=True
        )
        
        # Print search space summary
        tuner.search_space_summary()
        
        # Implement early stopping for the hyperparameter search
        stop_early = EarlyStopping(
            monitor='val_loss',
            min_delta=1e-4,
            patience=3
        )
        
        # Search with cross-validation
        tuner.search(
            training_features,
            training_labels,
            epochs=100,
            batch_size=batch_size,
            validation_data=validation_data,
            callbacks=self.get_callbacks(checkpoint_path),
            verbose=1
        )
        
        # Get best hyperparameters
        best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
        
        # Print detailed results
        print("\nBest Hyperparameters:")
        for param, value in best_hps.values.items():
            print(f"{param}: {value}")
        
        # Build and train final model with best parameters
        best_model = tuner.hypermodel.build(best_hps)
        
        history = best_model.fit(
            training_features,
            training_labels,
            epochs=100,
            batch_size=batch_size,
            validation_data=validation_data,
            callbacks=self.get_callbacks(checkpoint_path),
            verbose=1
        )
        
        return best_model, history, best_hps

# %%
tuner = BayesianNeuralTuner(
    input_shape=(training_features.shape[1],),
    max_trials=30,
    n_folds=3
)

best_model, history, best_hps = tuner.search(
    training_features,
    training_labels,
    validation_data=(validation_features, validation_labels)
)
# Out:
# Trial 30 Complete [00h 00m 13s]
# val_loss: 2496.394287109375
#
# Best val_loss So Far: 2384.412109375
# Total elapsed time: 00h 13m 21s
#
# Best Hyperparameters:
# dropout1: 0.2
# units1: 32
# l2_reg1: 0.0001
# units2: 32
# l2_reg2: 0.0001
# base_learning_rate: 0.01
# beta_1: 0.9074042879816304
# beta_2: 0.9294975412851051
# weight_decay: 0.00024867143636162013
# Epoch 1/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 63995.2422 - mape: 81.6180
# Epoch 1: val_loss improved from inf to 7431.98584, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 63657.0625 - mape: 81.2361 - val_loss: 7431.9858 - val_mape: 20.4650 - learning_rate: 0.0100
# Epoch 2/100
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9990.2363 - mape: 23.1349
# Epoch 2: val_loss improved from 7431.98584 to 7093.27246, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10169.7051 - mape: 23.1294 - val_loss: 7093.2725 - val_mape: 22.7326 - learning_rate: 0.0100
# Epoch 3/100
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8965.6865 - mape: 20.4058
# Epoch 3: val_loss improved from 7093.27246 to 6212.73047, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9047.0820 - mape: 20.4098 - val_loss: 6212.7305 - val_mape: 19.4183 - learning_rate: 0.0100
# Epoch 4/100
# 53/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7311.0840 - mape: 19.3137
# Epoch 4: val_loss improved from 6212.73047 to 5333.44727, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7657.4551 - mape: 19.2544 - val_loss: 5333.4473 - val_mape: 15.4925 - learning_rate: 0.0100
# Epoch 5/100
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8311.0889 - mape: 17.1272
# Epoch 5: val_loss improved from 5333.44727 to 5074.52197, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8311.1895 - mape: 17.1140 - val_loss: 5074.5220 - val_mape: 16.7512 - learning_rate: 0.0100
# Epoch 6/100
# 44/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6120.9277 - mape: 15.7580
# Epoch 6: val_loss improved from 5074.52197 to 4926.73047, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6601.0640 - mape: 15.8995 - val_loss: 4926.7305 - val_mape: 15.0383 - learning_rate: 0.0100
# Epoch 7/100
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9194.7744 - mape: 15.6277
# Epoch 7: val_loss did not improve from 4926.73047
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8990.7402 - mape: 15.6984 - val_loss: 4995.0576 - val_mape: 14.8973 - learning_rate: 0.0100
# Epoch 8/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6044.6484 - mape: 15.4836
# Epoch 8: val_loss improved from 4926.73047 to 4393.73926, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6038.9302 - mape: 15.5062 - val_loss: 4393.7393 - val_mape: 14.8737 - learning_rate: 0.0100
# Epoch 9/100
# 57/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7627.8862 - mape: 15.1929
# Epoch 9: val_loss did not improve from 4393.73926
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7542.7866 - mape: 15.2500 - val_loss: 4732.5415 - val_mape: 15.4179 - learning_rate: 0.0100
# Epoch 10/100
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4905.5635 - mape: 15.4347
# Epoch 10: val_loss did not improve from 4393.73926
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4979.2158 - mape: 15.4590 - val_loss: 4950.8452 - val_mape: 16.2260 - learning_rate: 0.0100
# Epoch 11/100
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3168.1194 - mape: 14.8757
# Epoch 11: val_loss improved from 4393.73926 to 4333.70752, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3430.0610 - mape: 14.9942 - val_loss: 4333.7075 - val_mape: 15.5839 - learning_rate: 0.0100
# Epoch 12/100
# 54/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5410.5151 - mape: 16.3018
# Epoch 12: val_loss improved from 4333.70752 to 4195.54150, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5292.5020 - mape: 16.2672 - val_loss: 4195.5415 - val_mape: 15.5642 - learning_rate: 0.0100
# Epoch 13/100
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4587.1499 - mape: 15.0001
# Epoch 13: val_loss improved from 4195.54150 to 3175.03320, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4664.7158 - mape: 15.0848 - val_loss: 3175.0332 - val_mape: 15.1086 - learning_rate: 0.0100
# Epoch 14/100
# 53/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3154.1001 - mape: 15.3298
# Epoch 14: val_loss did not improve from 3175.03320
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3193.5198 - mape: 15.3034 - val_loss: 3437.4268 - val_mape: 14.6015 - learning_rate: 0.0100
# Epoch 15/100
# 51/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3474.0215 - mape: 15.3208
# Epoch 15: val_loss did not improve from 3175.03320
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3467.7222 - mape: 15.3248 - val_loss: 3649.7949 - val_mape: 15.1167 - learning_rate: 0.0100
# Epoch 16/100
# 54/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3137.9617 - mape: 15.0685
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 16: val_loss did not improve from 3175.03320
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3125.5669 - mape: 15.0706 - val_loss: 3505.0750 - val_mape: 15.2620 - learning_rate: 0.0100
# Epoch 17/100
# 58/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3537.9185 - mape: 14.8791
# Epoch 17: val_loss improved from 3175.03320 to 2935.40625, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3605.1458 - mape: 14.9072 - val_loss: 2935.4062 - val_mape: 14.1721 - learning_rate: 0.0050
# Epoch 18/100
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2756.7634 - mape: 14.3509
# Epoch 18: val_loss improved from 2935.40625 to 2873.24341, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2760.6086 - mape: 14.3761 - val_loss: 2873.2434 - val_mape: 13.7954 - learning_rate: 0.0050
# Epoch 19/100
# 53/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3158.3774 - mape: 14.2964
# Epoch 19: val_loss did not improve from 2873.24341
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3345.9553 - mape: 14.4107 - val_loss: 3205.3386 - val_mape: 14.5547 - learning_rate: 0.0050
# Epoch 20/100
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3886.0740 - mape: 14.1396
# Epoch 20: val_loss improved from 2873.24341 to 2720.44702, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4034.8962 - mape: 14.1985 - val_loss: 2720.4470 - val_mape: 14.0738 - learning_rate: 0.0050
# Epoch 21/100
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2649.8213 - mape: 14.6459
# Epoch 21: val_loss improved from 2720.44702 to 2629.38037, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2663.3240 - mape: 14.6272 - val_loss: 2629.3804 - val_mape: 13.7015 - learning_rate: 0.0050
# Epoch 22/100
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2505.0203 - mape: 14.0609
# Epoch 22: val_loss improved from 2629.38037 to 2511.83057, saving model to logs/Kuchen/20250108-133319/best_model.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2506.2026 - mape: 14.0567 - val_loss: 2511.8306 - val_mape: 13.5512 - learning_rate: 0.0050
# Epoch 23/100
# 51/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2908.5134 - mape: 14.3276
# Epoch 23: val_loss did not improve from 2511.83057
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2892.2524 - mape: 14.3917 - val_loss: 3376.0557 - val_mape: 14.8498 - learning_rate: 0.0050
# Epoch 24/100
# 54/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2820.7178 - mape: 14.4771
# Epoch 24: val_loss did not improve from 2511.83057
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2811.4619 - mape: 14.5015 - val_loss: 3474.3352 - val_mape: 15.0522 - learning_rate: 0.0050
# Epoch 25/100
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8411.1934 - mape: 14.4701
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 25: val_loss did not improve from 2511.83057
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8165.7910 - mape: 14.4883 - val_loss: 2681.2043 - val_mape: 14.4552 - learning_rate: 0.0050
# Epoch 26/100
# 55/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6953.4292 - mape: 15.1979
# Epoch 26: val_loss did not improve from 2511.83057
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6774.7119 - mape: 15.1406 - val_loss: 2584.6948 - val_mape: 13.6781 - learning_rate: 0.0025
# Epoch 27/100
# 56/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2466.1636 - mape: 14.4297
# Epoch 27: val_loss did not improve from 2511.83057
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2462.8259 - mape: 14.4198 - val_loss: 2849.2502 - val_mape: 13.8134 - learning_rate: 0.0025
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Überwachung der Validierungsverlust
    patience=10,         # Anzahl der Epochen ohne Verbesserung
    restore_best_weights=True  # Stellt das Modell mit den besten Gewichten wieder her
)
# Train the final model
history = best_model.fit(
    training_features,
    training_labels,
    epochs=100,
    batch_size=24,
    validation_data=(validation_features, validation_labels),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8275.2910 - mape: 15.2676 - val_loss: 2619.6111 - val_mape: 13.5310
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 