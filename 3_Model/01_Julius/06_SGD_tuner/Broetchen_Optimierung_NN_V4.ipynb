# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, AdamW
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
# Out:
# 2025-01-06 21:48:42.635374: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-06 21:48:42.781623: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736196522.854233 1671770 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736196522.872348 1671770 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-06 21:48:42.995863: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define the file paths
subdirectory = "pickle_data_Broetchen"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())
# Out:
# Loaded Training features dimensions: (1462, 24)
# Loaded Validation features dimensions: (357, 24)
# Loaded Test features dimensions: (355, 24)
#
# Loaded Training labels dimensions: (1462, 1)
# Loaded Validation labels dimensions: (357, 1)
#
# First few rows of loaded training features:
#       Temp_Cold_current  Temp_Mild_current  Temp_Warm_current  \
# 1819                  0                  1                  0
# 1820                  0                  1                  0
# 1821                  0                  0                  1
# 1822                  0                  1                  0
# 1823                  0                  1                  0
#
#       Temp_Hot_current  Cloud_ok_current  Cloud_Cloudy_current  \
# 1819                 0                 0                     1
# 1820                 0                 1                     0
# 1821                 0                 0                     1
# 1822                 0                 0                     1
# 1823                 0                 1                     0
#
#       KielerWoche_current  Samstag_current  Sonntag_current  VPI_current  ...  \
# 1819                    0                0                0        0.052  ...
# 1820                    0                0                0        0.052  ...
# 1821                    0                0                0        0.052  ...
# 1822                    0                0                0        0.052  ...
# 1823                    0                0                0        0.052  ...
#
#       Ostertag_current  Silvester_current  Werktag_current  Sommer_current  \
# 1819                 0                  0                1               1
# 1820                 0                  0                1               1
# 1821                 0                  0                1               1
# 1822                 0                  0                1               1
# 1823                 0                  0                1               1
#
#       Winter_current  wetter_sehr_schlecht_current  wetter_sehr_schön_current  \
# 1819               0                             0                          0
# 1820               0                             0                          0
# 1821               0                             1                          0
# 1822               0                             0                          0
# 1823               0                             0                          0
#
#       Monat_7_current  Monat_1_current  is_holiday_next
# 1819                1                0              1.0
# 1820                1                0              1.0
# 1821                1                0              1.0
# 1822                1                0              1.0
# 1823                1                0              1.0
#
# [5 rows x 24 columns]
#
# First few rows of loaded training labels:
#           Umsatz
# 1819  535.856285
# 1820  546.780787
# 1821  427.343259
# 1822  454.859641
# 1823  492.818804

# %%
#Defining the Neural Network
#Now, let's define our neural network. We are using a Sequential model definition from Keras with batch normalization and dense layers.

model = Sequential([
    InputLayer(shape=(training_features.shape[1], )),
    Dropout(0.1),
    Dense(50, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.01)),
    Dropout(0.15),
    Dense(25, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.01)),

    Dense(1)
])

model.summary()
# Out:
# I0000 00:00:1736196523.768374 1671770 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │         1,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,551 (9.96 KB)
#  Trainable params: 2,551 (9.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# SGD with optimized parameters
optimizer = SGD(
    #learning_rate=0.003, durch den lr_scheduler geregelt
    momentum=0.9,    # Add momentum to help escape local minima
    nesterov=True,   # Use Nesterov momentum for better convergence
)

model.compile(
    loss="huber",    # More robust to outliers
    optimizer=optimizer,
    metrics=['mape']
)

# Custom learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.5
    epochs_drop = 50.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return max(lr, 1e-5)  # Don't let LR get too small

history = model.fit(
    training_features, 
    training_labels, 
    epochs=500,
    batch_size=8,   # Smaller batch size works better with SGD
    verbose=1,
    validation_data=(validation_features, validation_labels),
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            mode='min'
        ),
        LearningRateScheduler(lr_schedule),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_loss',
            save_best_only=True,
            mode='min'
        )
    ]
)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736196525.144286 1671875 service.cc:148] XLA service 0x7f2be4009060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736196525.144536 1671875 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-01-06 21:48:45.171802: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736196525.243420 1671875 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  68/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 407.6516 - mape: 99.3709
# I0000 00:00:1736196526.773204 1671875 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 347.5940 - mape: 84.1418 - val_loss: 55.0287 - val_mape: 16.5515 - learning_rate: 0.0010
# Epoch 2/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 73.1499 - mape: 17.4923 - val_loss: 49.0526 - val_mape: 13.4665 - learning_rate: 0.0010
# Epoch 3/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 70.8125 - mape: 16.6767 - val_loss: 53.0948 - val_mape: 13.5069 - learning_rate: 0.0010
# Epoch 4/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 68.9082 - mape: 16.3182 - val_loss: 45.9441 - val_mape: 12.4524 - learning_rate: 0.0010
# Epoch 5/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 67.8631 - mape: 15.8935 - val_loss: 51.6899 - val_mape: 14.8565 - learning_rate: 0.0010
# Epoch 6/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 67.2587 - mape: 15.9149 - val_loss: 55.2181 - val_mape: 13.8498 - learning_rate: 0.0010
# Epoch 7/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 69.3949 - mape: 16.3030 - val_loss: 47.5870 - val_mape: 13.4088 - learning_rate: 0.0010
# Epoch 8/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.1617 - mape: 15.0860 - val_loss: 46.9964 - val_mape: 12.9579 - learning_rate: 0.0010
# Epoch 9/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 65.8291 - mape: 15.6072 - val_loss: 45.0217 - val_mape: 11.8772 - learning_rate: 0.0010
# Epoch 10/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.7189 - mape: 15.3019 - val_loss: 46.1582 - val_mape: 12.1448 - learning_rate: 0.0010
# Epoch 11/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.8839 - mape: 15.7149 - val_loss: 51.3446 - val_mape: 14.5717 - learning_rate: 0.0010
# Epoch 12/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 70.2636 - mape: 16.8511 - val_loss: 44.0404 - val_mape: 11.6547 - learning_rate: 0.0010
# Epoch 13/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.6137 - mape: 14.5143 - val_loss: 42.7525 - val_mape: 11.1604 - learning_rate: 0.0010
# Epoch 14/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 65.4623 - mape: 15.5074 - val_loss: 42.5548 - val_mape: 11.4506 - learning_rate: 0.0010
# Epoch 15/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.9571 - mape: 15.1312 - val_loss: 52.9215 - val_mape: 12.9676 - learning_rate: 0.0010
# Epoch 16/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 63.4872 - mape: 14.9836 - val_loss: 46.5358 - val_mape: 12.6341 - learning_rate: 0.0010
# Epoch 17/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.5474 - mape: 14.9277 - val_loss: 49.6344 - val_mape: 14.8336 - learning_rate: 0.0010
# Epoch 18/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 64.2047 - mape: 15.1963 - val_loss: 45.8146 - val_mape: 11.9658 - learning_rate: 0.0010
# Epoch 19/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.7944 - mape: 15.3166 - val_loss: 44.9484 - val_mape: 11.4849 - learning_rate: 0.0010
# Epoch 20/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.9910 - mape: 14.5592 - val_loss: 44.8523 - val_mape: 12.3406 - learning_rate: 0.0010
# Epoch 21/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 64.2533 - mape: 15.1946 - val_loss: 45.0919 - val_mape: 11.6625 - learning_rate: 0.0010
# Epoch 22/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 62.8338 - mape: 14.8657 - val_loss: 44.6866 - val_mape: 11.4956 - learning_rate: 0.0010
# Epoch 23/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 61.7065 - mape: 14.5420 - val_loss: 44.9883 - val_mape: 12.2196 - learning_rate: 0.0010
# Epoch 24/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.6407 - mape: 14.1619 - val_loss: 46.9375 - val_mape: 13.2727 - learning_rate: 0.0010
# Epoch 25/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 62.4283 - mape: 14.6103 - val_loss: 43.7509 - val_mape: 11.3049 - learning_rate: 0.0010
# Epoch 26/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 64.2726 - mape: 14.3955 - val_loss: 42.2058 - val_mape: 11.5950 - learning_rate: 0.0010
# Epoch 27/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 62.0917 - mape: 14.6829 - val_loss: 44.6542 - val_mape: 11.2547 - learning_rate: 0.0010
# Epoch 28/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 62.6201 - mape: 14.4420 - val_loss: 43.3919 - val_mape: 11.2309 - learning_rate: 0.0010
# Epoch 29/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.5335 - mape: 14.3794 - val_loss: 44.6223 - val_mape: 11.6261 - learning_rate: 0.0010
# Epoch 30/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.2946 - mape: 15.3376 - val_loss: 49.6032 - val_mape: 12.7199 - learning_rate: 0.0010
# Epoch 31/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 62.7154 - mape: 14.7617 - val_loss: 44.4314 - val_mape: 11.5946 - learning_rate: 0.0010
# Epoch 32/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 63.8197 - mape: 14.7435 - val_loss: 43.1683 - val_mape: 11.5188 - learning_rate: 0.0010
# Epoch 33/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 63.0913 - mape: 14.4634 - val_loss: 50.3082 - val_mape: 12.5312 - learning_rate: 0.0010
# Epoch 34/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ -1s -6554us/step - loss: 63.4935 - mape: 14.7884 - val_loss: 45.7729 - val_mape: 13.0716 - learning_rate: 0.0010
# Epoch 35/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 61.2634 - mape: 14.6758 - val_loss: 50.6988 - val_mape: 15.1448 - learning_rate: 0.0010
# Epoch 36/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.2200 - mape: 14.6263 - val_loss: 44.3759 - val_mape: 12.7678 - learning_rate: 0.0010
# Epoch 37/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 61.2291 - mape: 14.5189 - val_loss: 41.3396 - val_mape: 11.1852 - learning_rate: 0.0010
# Epoch 38/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 61.2813 - mape: 14.1875 - val_loss: 51.7151 - val_mape: 12.3757 - learning_rate: 0.0010
# Epoch 39/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 63.0220 - mape: 14.3852 - val_loss: 45.6019 - val_mape: 11.4367 - learning_rate: 0.0010
# Epoch 40/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.4155 - mape: 14.1851 - val_loss: 46.9711 - val_mape: 12.7291 - learning_rate: 0.0010
# Epoch 41/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 64.7405 - mape: 14.9817 - val_loss: 48.1288 - val_mape: 12.6991 - learning_rate: 0.0010
# Epoch 42/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 62.5752 - mape: 14.6839 - val_loss: 43.5925 - val_mape: 11.1359 - learning_rate: 0.0010
# Epoch 43/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 61.7931 - mape: 14.1312 - val_loss: 41.7211 - val_mape: 10.7407 - learning_rate: 0.0010
# Epoch 44/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 58.1002 - mape: 13.7098 - val_loss: 44.0909 - val_mape: 11.3338 - learning_rate: 0.0010
# Epoch 45/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 59.8840 - mape: 14.1876 - val_loss: 43.5741 - val_mape: 12.0886 - learning_rate: 0.0010
# Epoch 46/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 59.7137 - mape: 13.8598 - val_loss: 44.3432 - val_mape: 12.2197 - learning_rate: 0.0010
# Epoch 47/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.8983 - mape: 14.3482 - val_loss: 43.3178 - val_mape: 12.3982 - learning_rate: 0.0010
# Epoch 48/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.6379 - mape: 14.3940 - val_loss: 44.2606 - val_mape: 12.4296 - learning_rate: 0.0010
# Epoch 49/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 61.1594 - mape: 14.2528 - val_loss: 45.3736 - val_mape: 13.1093 - learning_rate: 0.0010
# Epoch 50/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 58.9639 - mape: 14.0684 - val_loss: 43.8135 - val_mape: 12.4448 - learning_rate: 5.0000e-04
# Epoch 51/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 59.7050 - mape: 14.0609 - val_loss: 44.2169 - val_mape: 11.8937 - learning_rate: 5.0000e-04
# Epoch 52/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.5633 - mape: 13.5506 - val_loss: 48.6594 - val_mape: 12.7069 - learning_rate: 5.0000e-04
# Epoch 53/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.0979 - mape: 13.6534 - val_loss: 45.9630 - val_mape: 12.2532 - learning_rate: 5.0000e-04
# Epoch 54/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.5007 - mape: 13.6730 - val_loss: 44.3765 - val_mape: 12.6943 - learning_rate: 5.0000e-04
# Epoch 55/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 55.1562 - mape: 12.9051 - val_loss: 44.1886 - val_mape: 12.5107 - learning_rate: 5.0000e-04
# Epoch 56/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 57.7415 - mape: 13.7665 - val_loss: 51.4642 - val_mape: 12.9316 - learning_rate: 5.0000e-04
# Epoch 57/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 55.8874 - mape: 13.1542 - val_loss: 46.7373 - val_mape: 12.6360 - learning_rate: 5.0000e-04

# %%
# Saving the trained Model
model.save("python_model_Broetchen.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making Predictions and Evaluating the Model
import numpy as np

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# MAPE on the Training Data: 12.08%
# MAPE on the Validation Data: 11.19%

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='Training MAPE')
plt.plot(history.history['val_mape'], label='Validation MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_predictions(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['actual'], label='Actual Values', color='red')
    plt.plot(data['prediction'], label='Predicted Values', color='blue')
    plt.title(title)
    plt.xlabel('Zeit')
    plt.ylabel('Umsatz')
    plt.legend()
    plt.show()

# Ensure that training_predictions, validation_predictions, training_labels, and validation_labels are numpy arrays
training_predictions = np.array(training_predictions).flatten()
validation_predictions = np.array(validation_predictions).flatten()
training_labels = np.array(training_labels).flatten()
validation_labels = np.array(validation_labels).flatten()

# print the type of the predictions
print(type(training_predictions))
print(type(validation_predictions))

# Create DataFrames with 1-dimensional arrays
data_train = pd.DataFrame({'prediction': training_predictions, 'actual': training_labels})
data_validation = pd.DataFrame({'prediction': validation_predictions, 'actual': validation_labels})

# Plot predictions
plot_predictions(data_train.head(100), 'Predicted and Actual Values for the Training Data')
plot_predictions(data_validation.head(100), 'Predicted and Actual Values for the Validation Data')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ***VORHERSAGE TESTZEITRAUM***

# %%
test_predictions = model.predict(test_features)
#print("Predictions for test data:", test_predictions[:5])  # Display first 5 predictions
# Größe des Arrays anzeigen
print("Größe des Arrays (shape):", test_predictions.shape)
test_predictions = pd.DataFrame(test_predictions)
test_predictions
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# Größe des Arrays (shape): (355, 1)
#               0
# 0    502.268188
# 1    513.612122
# 2    513.612122
# 3    654.270935
# 4    625.203491
# ..          ...
# 350  517.578186
# 351  632.614868
# 352  656.749268
# 353  524.441528
# 354  518.551819
#
# [355 rows x 1 columns]

# %%
data_test = pd.read_csv("../../../0_DataPreparation/00_data/data_with_lag/Testdaten_with_lag.csv")
data_test = data_test[data_test["Warengruppe_2"] == 1]
data_test
# Out:
#           id       Datum  Warengruppe_1  Warengruppe_2  Warengruppe_3  \
# 355  1808012  2018-08-01              0              1              0
# 356  1808022  2018-08-02              0              1              0
# 357  1808032  2018-08-03              0              1              0
# 358  1808042  2018-08-04              0              1              0
# 359  1808052  2018-08-05              0              1              0
# ..       ...         ...            ...            ...            ...
# 705  1907262  2019-07-26              0              1              0
# 706  1907272  2019-07-27              0              1              0
# 707  1907282  2019-07-28              0              1              0
# 708  1907292  2019-07-29              0              1              0
# 709  1907302  2019-07-30              0              1              0
#
#      Warengruppe_4  Warengruppe_5  Warengruppe_6  Temp_Very_Cold_current  \
# 355              0              0              0                       0
# 356              0              0              0                       0
# 357              0              0              0                       0
# 358              0              0              0                       0
# 359              0              0              0                       0
# ..             ...            ...            ...                     ...
# 705              0              0              0                       0
# 706              0              0              0                       0
# 707              0              0              0                       0
# 708              0              0              0                       0
# 709              0              0              0                       0
#
#      Temp_Very_Cold_prev  ...  zwischen_den_jahren_next  \
# 355                  0.0  ...                       0.0
# 356                  0.0  ...                       0.0
# 357                  0.0  ...                       0.0
# 358                  0.0  ...                       0.0
# 359                  0.0  ...                       0.0
# ..                   ...  ...                       ...
# 705                  0.0  ...                       0.0
# 706                  0.0  ...                       0.0
# 707                  0.0  ...                       0.0
# 708                  0.0  ...                       0.0
# 709                  0.0  ...                       0.0
#
#      Number_of_ships_scaled_current  Number_of_ships_scaled_prev  \
# 355                             0.0                          0.2
# 356                             0.0                          0.0
# 357                             0.0                          0.0
# 358                             0.2                          0.0
# 359                             0.0                          0.2
# ..                              ...                          ...
# 705                             0.0                          0.2
# 706                             0.6                          0.0
# 707                             0.4                          0.6
# 708                             0.2                          0.4
# 709                             0.2                          0.2
#
#      Number_of_ships_scaled_next  Cloud_ok_current  Cloud_ok_prev  \
# 355                          0.0                 1            0.0
# 356                          0.0                 1            1.0
# 357                          0.2                 1            1.0
# 358                          0.0                 1            1.0
# 359                          0.0                 0            1.0
# ..                           ...               ...            ...
# 705                          0.6                 1            0.0
# 706                          0.4                 1            1.0
# 707                          0.2                 1            1.0
# 708                          0.2                 0            1.0
# 709                          0.0                 0            0.0
#
#      Cloud_ok_next  Wind_ok_current  Wind_ok_prev  Wind_ok_next
# 355            1.0                1           1.0           1.0
# 356            1.0                1           1.0           1.0
# 357            1.0                1           1.0           1.0
# 358            0.0                1           1.0           1.0
# 359            1.0                1           1.0           1.0
# ..             ...              ...           ...           ...
# 705            1.0                1           1.0           0.0
# 706            1.0                0           1.0           1.0
# 707            0.0                1           0.0           1.0
# 708            0.0                1           1.0           1.0
# 709            1.0                1           1.0           1.0
#
# [355 rows x 176 columns]

# %%
# Erstelle Ziel csv Datei

predictions_df = pd.DataFrame({
    'id': data_test['id'].values,
    'Umsatz': test_predictions[0].values
}).reset_index(drop=True)

# Save to a CSV file
#output_csv_path = "/workspaces/bakery_sales_prediction/3_Model/02_Franz/V3_lag/Umsatzvorhersage_Broetchen_Hochladeformat.csv"

predictions_df.to_csv('Broetchen_Umsatzvorhersage.csv', index=False)
print(f"CSV Datei erstellt")
# Out:
# CSV Datei erstellt
