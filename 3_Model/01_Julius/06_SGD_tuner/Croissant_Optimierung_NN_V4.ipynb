# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, AdamW
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
# Out:
# 2025-01-05 22:58:16.495378: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-05 22:58:16.520612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736114296.542105 1442393 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736114296.547657 1442393 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 22:58:16.576774: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define the file paths
subdirectory = "pickle_data_Croissant"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())
# Out:
# Loaded Training features dimensions: (1462, 25)
# Loaded Validation features dimensions: (357, 25)
# Loaded Test features dimensions: (355, 25)
#
# Loaded Training labels dimensions: (1462, 1)
# Loaded Validation labels dimensions: (357, 1)
#
# First few rows of loaded training features:
#       Temp_Very_Cold_current  Temp_Cold_current  Temp_Mild_current  \
# 3638                       0                  0                  1
# 3639                       0                  0                  1
# 3640                       0                  0                  0
# 3641                       0                  0                  1
# 3642                       0                  0                  1
#
#       Temp_Warm_current  Temp_Hot_current  Cloud_ok_current  \
# 3638                  0                 0                 0
# 3639                  0                 0                 1
# 3640                  1                 0                 0
# 3641                  0                 0                 0
# 3642                  0                 0                 1
#
#       Cloud_Cloudy_current  KielerWoche_current  Samstag_current  \
# 3638                     1                    0                0
# 3639                     0                    0                0
# 3640                     1                    0                0
# 3641                     1                    0                0
# 3642                     0                    0                0
#
#       Sonntag_current  ...  Werktag_current  Frühling_current  Sommer_current  \
# 3638                0  ...                1                 0               1
# 3639                0  ...                1                 0               1
# 3640                0  ...                1                 0               1
# 3641                0  ...                1                 0               1
# 3642                0  ...                1                 0               1
#
#       Herbst_current  Winter_current  wetter_sehr_schlecht_current  \
# 3638               0               0                             0
# 3639               0               0                             0
# 3640               0               0                             1
# 3641               0               0                             0
# 3642               0               0                             0
#
#       wetter_sehr_schön_current  Monat_8_current  Monat_7_current  \
# 3638                          0                0                1
# 3639                          0                0                1
# 3640                          0                0                1
# 3641                          0                0                1
# 3642                          0                0                1
#
#       wetter_sehr_schön_prev
# 3638                     0.0
# 3639                     0.0
# 3640                     0.0
# 3641                     0.0
# 3642                     0.0
#
# [5 rows x 25 columns]
#
# First few rows of loaded training labels:
#           Umsatz
# 3638  201.198426
# 3639  265.261254
# 3640  210.260241
# 3641  190.686641
# 3642  181.644870

# %%
#Defining the Neural Network
#Now, let's define our neural network. We are using a Sequential model definition from Keras with batch normalization and dense layers.

model = Sequential([
    InputLayer(shape=(training_features.shape[1], )),
    Dropout(0.1),
    Dense(50, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.01)),
    Dropout(0.15),
    Dense(25, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.01)),

    Dense(1)
])

model.summary()
# Out:
# I0000 00:00:1736114298.557841 1442393 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2051 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,601 (10.16 KB)
#  Trainable params: 2,601 (10.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# SGD with optimized parameters
optimizer = SGD(
    #learning_rate=0.003, durch den lr_scheduler geregelt
    momentum=0.9,    # Add momentum to help escape local minima
    nesterov=True,   # Use Nesterov momentum for better convergence
)

model.compile(
    loss="huber",    # More robust to outliers
    optimizer=optimizer,
    metrics=['mape']
)

# Custom learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.003
    drop = 0.5
    epochs_drop = 50.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return max(lr, 1e-5)  # Don't let LR get too small

history = model.fit(
    training_features, 
    training_labels, 
    epochs=500,
    batch_size=16,   # Smaller batch size works better with SGD
    verbose=1,
    validation_data=(validation_features, validation_labels),
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=100,
            restore_best_weights=True,
            mode='min'
        ),
        LearningRateScheduler(lr_schedule),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_loss',
            save_best_only=True,
            mode='min'
        )
    ]
)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736114301.203158 1442889 service.cc:148] XLA service 0x7ff31c003380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736114301.203235 1442889 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-01-05 22:58:21.228022: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736114301.303876 1442889 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 36/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 158.4103 - mape: 95.8131
# I0000 00:00:1736114302.376832 1442889 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 126.3732 - mape: 76.8732 - val_loss: 35.0161 - val_mape: 20.1301 - learning_rate: 0.0030
# Epoch 2/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 39.4780 - mape: 23.4622 - val_loss: 31.8917 - val_mape: 19.3384 - learning_rate: 0.0030
# Epoch 3/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.5736 - mape: 22.1670 - val_loss: 32.9248 - val_mape: 21.3364 - learning_rate: 0.0030
# Epoch 4/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 34.8989 - mape: 22.2155 - val_loss: 33.4503 - val_mape: 19.6232 - learning_rate: 0.0030
# Epoch 5/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.0584 - mape: 21.8580 - val_loss: 42.9625 - val_mape: 23.5625 - learning_rate: 0.0030
# Epoch 6/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.3892 - mape: 20.9312 - val_loss: 31.6213 - val_mape: 20.3293 - learning_rate: 0.0030
# Epoch 7/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.8078 - mape: 21.4702 - val_loss: 34.8508 - val_mape: 20.3358 - learning_rate: 0.0030
# Epoch 8/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.3894 - mape: 21.5032 - val_loss: 29.8998 - val_mape: 17.7717 - learning_rate: 0.0030
# Epoch 9/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.3028 - mape: 20.6001 - val_loss: 31.3379 - val_mape: 19.1642 - learning_rate: 0.0030
# Epoch 10/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.5145 - mape: 20.6072 - val_loss: 32.8528 - val_mape: 18.8353 - learning_rate: 0.0030
# Epoch 11/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.8399 - mape: 20.7958 - val_loss: 36.6767 - val_mape: 20.5528 - learning_rate: 0.0030
# Epoch 12/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ -2s -17146us/step - loss: 31.7227 - mape: 20.2762 - val_loss: 41.9618 - val_mape: 22.9865 - learning_rate: 0.0030
# Epoch 13/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.5010 - mape: 20.7192 - val_loss: 32.1065 - val_mape: 21.3110 - learning_rate: 0.0030
# Epoch 14/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.5852 - mape: 20.1643 - val_loss: 30.7211 - val_mape: 18.5317 - learning_rate: 0.0030
# Epoch 15/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.5095 - mape: 19.9521 - val_loss: 31.7991 - val_mape: 18.6655 - learning_rate: 0.0030
# Epoch 16/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.4300 - mape: 20.1998 - val_loss: 33.9915 - val_mape: 19.2571 - learning_rate: 0.0030
# Epoch 17/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.6902 - mape: 20.5206 - val_loss: 30.9160 - val_mape: 18.8844 - learning_rate: 0.0030
# Epoch 18/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.6595 - mape: 20.7496 - val_loss: 31.2947 - val_mape: 18.3327 - learning_rate: 0.0030
# Epoch 19/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.8384 - mape: 19.9039 - val_loss: 29.7405 - val_mape: 18.3544 - learning_rate: 0.0030
# Epoch 20/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.6317 - mape: 20.4344 - val_loss: 33.3685 - val_mape: 19.2679 - learning_rate: 0.0030
# Epoch 21/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.1757 - mape: 20.0169 - val_loss: 30.9885 - val_mape: 18.6582 - learning_rate: 0.0030
# Epoch 22/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 32.2474 - mape: 19.9156 - val_loss: 33.7892 - val_mape: 20.0735 - learning_rate: 0.0030
# Epoch 23/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.7135 - mape: 19.0714 - val_loss: 34.2180 - val_mape: 19.4150 - learning_rate: 0.0030
# Epoch 24/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.8614 - mape: 20.1225 - val_loss: 35.7597 - val_mape: 19.8912 - learning_rate: 0.0030
# Epoch 25/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33.1702 - mape: 20.0534 - val_loss: 35.9317 - val_mape: 20.3152 - learning_rate: 0.0030
# Epoch 26/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.3040 - mape: 20.9942 - val_loss: 31.5092 - val_mape: 19.6816 - learning_rate: 0.0030
# Epoch 27/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.1499 - mape: 19.6963 - val_loss: 34.0379 - val_mape: 19.3579 - learning_rate: 0.0030
# Epoch 28/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.6315 - mape: 19.2308 - val_loss: 32.5751 - val_mape: 20.3442 - learning_rate: 0.0030
# Epoch 29/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 31.3688 - mape: 19.6339 - val_loss: 31.1102 - val_mape: 20.3059 - learning_rate: 0.0030
# Epoch 30/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.6298 - mape: 20.0014 - val_loss: 31.3973 - val_mape: 19.5788 - learning_rate: 0.0030
# Epoch 31/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30.8189 - mape: 19.4098 - val_loss: 31.7708 - val_mape: 18.8665 - learning_rate: 0.0030
# Epoch 32/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.8565 - mape: 20.0946 - val_loss: 32.4610 - val_mape: 20.8989 - learning_rate: 0.0030
# Epoch 33/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.6890 - mape: 20.4260 - val_loss: 30.6377 - val_mape: 18.5494 - learning_rate: 0.0030
# Epoch 34/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.7254 - mape: 19.1335 - val_loss: 29.7280 - val_mape: 19.2082 - learning_rate: 0.0030
# Epoch 35/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.1423 - mape: 19.8550 - val_loss: 30.7274 - val_mape: 19.2770 - learning_rate: 0.0030
# Epoch 36/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.6205 - mape: 20.0956 - val_loss: 32.3144 - val_mape: 18.7564 - learning_rate: 0.0030
# Epoch 37/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.7278 - mape: 20.5325 - val_loss: 30.7586 - val_mape: 20.3226 - learning_rate: 0.0030
# Epoch 38/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.9662 - mape: 19.9860 - val_loss: 30.3609 - val_mape: 18.1245 - learning_rate: 0.0030
# Epoch 39/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.2558 - mape: 20.2860 - val_loss: 33.7492 - val_mape: 19.3832 - learning_rate: 0.0030
# Epoch 40/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31.2722 - mape: 18.8567 - val_loss: 30.9805 - val_mape: 19.0902 - learning_rate: 0.0030
# Epoch 41/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.2802 - mape: 19.0996 - val_loss: 29.9676 - val_mape: 18.9871 - learning_rate: 0.0030
# Epoch 42/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.1692 - mape: 19.9934 - val_loss: 30.7286 - val_mape: 19.4368 - learning_rate: 0.0030
# Epoch 43/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.5004 - mape: 19.8894 - val_loss: 30.6965 - val_mape: 19.8526 - learning_rate: 0.0030
# Epoch 44/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32.1275 - mape: 20.4460 - val_loss: 32.9243 - val_mape: 19.0593 - learning_rate: 0.0030
# Epoch 45/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.9903 - mape: 20.0858 - val_loss: 33.8043 - val_mape: 19.3269 - learning_rate: 0.0030
# Epoch 46/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31.7011 - mape: 19.7898 - val_loss: 32.3542 - val_mape: 18.9289 - learning_rate: 0.0030
# Epoch 47/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.4948 - mape: 19.6117 - val_loss: 30.4518 - val_mape: 19.6233 - learning_rate: 0.0030
# Epoch 48/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.7057 - mape: 19.4345 - val_loss: 31.5034 - val_mape: 18.4865 - learning_rate: 0.0030
# Epoch 49/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.2904 - mape: 20.3452 - val_loss: 31.9786 - val_mape: 18.4650 - learning_rate: 0.0030
# Epoch 50/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.7136 - mape: 18.6870 - val_loss: 30.1830 - val_mape: 19.2563 - learning_rate: 0.0015
# Epoch 51/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.7879 - mape: 19.7080 - val_loss: 32.1553 - val_mape: 18.8365 - learning_rate: 0.0015
# Epoch 52/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31.9332 - mape: 19.7921 - val_loss: 31.0214 - val_mape: 18.5528 - learning_rate: 0.0015
# Epoch 53/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.5259 - mape: 19.5356 - val_loss: 29.0421 - val_mape: 18.2315 - learning_rate: 0.0015
# Epoch 54/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.3883 - mape: 19.6735 - val_loss: 31.0146 - val_mape: 19.5072 - learning_rate: 0.0015
# Epoch 55/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.0811 - mape: 19.1361 - val_loss: 31.1057 - val_mape: 18.6241 - learning_rate: 0.0015
# Epoch 56/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.8164 - mape: 19.0138 - val_loss: 31.4750 - val_mape: 19.3153 - learning_rate: 0.0015
# Epoch 57/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.5889 - mape: 18.7358 - val_loss: 31.4029 - val_mape: 18.8964 - learning_rate: 0.0015
# Epoch 58/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.1432 - mape: 18.8738 - val_loss: 31.3729 - val_mape: 18.7375 - learning_rate: 0.0015
# Epoch 59/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.9319 - mape: 19.4494 - val_loss: 29.7525 - val_mape: 18.0913 - learning_rate: 0.0015
# Epoch 60/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0925 - mape: 18.6686 - val_loss: 32.1139 - val_mape: 19.6035 - learning_rate: 0.0015
# Epoch 61/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1397 - mape: 18.8832 - val_loss: 30.8186 - val_mape: 18.5202 - learning_rate: 0.0015
# Epoch 62/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.8140 - mape: 19.9258 - val_loss: 30.7871 - val_mape: 19.8362 - learning_rate: 0.0015
# Epoch 63/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.8031 - mape: 19.0541 - val_loss: 29.5289 - val_mape: 17.9945 - learning_rate: 0.0015
# Epoch 64/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31.3108 - mape: 19.8879 - val_loss: 30.8593 - val_mape: 18.3714 - learning_rate: 0.0015
# Epoch 65/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1207 - mape: 19.5072 - val_loss: 30.1307 - val_mape: 18.6475 - learning_rate: 0.0015
# Epoch 66/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.6101 - mape: 19.4083 - val_loss: 30.3686 - val_mape: 19.0614 - learning_rate: 0.0015
# Epoch 67/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.7026 - mape: 19.4524 - val_loss: 30.4418 - val_mape: 18.7721 - learning_rate: 0.0015
# Epoch 68/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1646 - mape: 18.5259 - val_loss: 30.9831 - val_mape: 18.8988 - learning_rate: 0.0015
# Epoch 69/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.2609 - mape: 20.2064 - val_loss: 31.3363 - val_mape: 18.2828 - learning_rate: 0.0015
# Epoch 70/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.1990 - mape: 18.9929 - val_loss: 30.5208 - val_mape: 18.1501 - learning_rate: 0.0015
# Epoch 71/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.1872 - mape: 19.1670 - val_loss: 30.7670 - val_mape: 19.1671 - learning_rate: 0.0015
# Epoch 72/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.3280 - mape: 18.5329 - val_loss: 32.3059 - val_mape: 19.0218 - learning_rate: 0.0015
# Epoch 73/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.6197 - mape: 18.7886 - val_loss: 29.6886 - val_mape: 18.2109 - learning_rate: 0.0015
# Epoch 74/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.9127 - mape: 18.5709 - val_loss: 32.1426 - val_mape: 19.3486 - learning_rate: 0.0015
# Epoch 75/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.0511 - mape: 20.0386 - val_loss: 30.0292 - val_mape: 18.2013 - learning_rate: 0.0015
# Epoch 76/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.8615 - mape: 18.6601 - val_loss: 30.1387 - val_mape: 18.5962 - learning_rate: 0.0015
# Epoch 77/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.7918 - mape: 20.0941 - val_loss: 29.8504 - val_mape: 18.5556 - learning_rate: 0.0015
# Epoch 78/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 29.9576 - mape: 19.2321 - val_loss: 31.2444 - val_mape: 18.9588 - learning_rate: 0.0015
# Epoch 79/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.3929 - mape: 18.9518 - val_loss: 31.3416 - val_mape: 18.5316 - learning_rate: 0.0015
# Epoch 80/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 30.5376 - mape: 19.2094 - val_loss: 29.7383 - val_mape: 18.4162 - learning_rate: 0.0015
# Epoch 81/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 31.0707 - mape: 19.7089 - val_loss: 29.7903 - val_mape: 18.3163 - learning_rate: 0.0015
# Epoch 82/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 30.4759 - mape: 19.0180 - val_loss: 30.4504 - val_mape: 18.2229 - learning_rate: 0.0015
# Epoch 83/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30.0011 - mape: 18.7628 - val_loss: 31.3599 - val_mape: 19.1610 - learning_rate: 0.0015
# Epoch 84/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ -1s -16233us/step - loss: 30.7856 - mape: 19.0014 - val_loss: 31.7563 - val_mape: 18.5072 - learning_rate: 0.0015
# Epoch 85/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30.8169 - mape: 19.0455 - val_loss: 32.4054 - val_mape: 19.2207 - learning_rate: 0.0015
# Epoch 86/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.5276 - mape: 18.9412 - val_loss: 30.3543 - val_mape: 20.7339 - learning_rate: 0.0015
# Epoch 87/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.1538 - mape: 19.7074 - val_loss: 31.6300 - val_mape: 19.0373 - learning_rate: 0.0015
# Epoch 88/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.2129 - mape: 19.3879 - val_loss: 33.4817 - val_mape: 19.3326 - learning_rate: 0.0015
# Epoch 89/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.1325 - mape: 19.7651 - val_loss: 32.8394 - val_mape: 19.2339 - learning_rate: 0.0015
# Epoch 90/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.7782 - mape: 18.7474 - val_loss: 31.0648 - val_mape: 18.9870 - learning_rate: 0.0015
# Epoch 91/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.1997 - mape: 19.2346 - val_loss: 30.4968 - val_mape: 18.4748 - learning_rate: 0.0015
# Epoch 92/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.9987 - mape: 19.5396 - val_loss: 31.4704 - val_mape: 18.9513 - learning_rate: 0.0015
# Epoch 93/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8440 - mape: 18.4466 - val_loss: 30.7503 - val_mape: 18.8770 - learning_rate: 0.0015
# Epoch 94/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.1651 - mape: 19.0436 - val_loss: 30.6673 - val_mape: 18.4315 - learning_rate: 0.0015
# Epoch 95/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0150 - mape: 18.4739 - val_loss: 33.9130 - val_mape: 19.7660 - learning_rate: 0.0015
# Epoch 96/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.7762 - mape: 19.9649 - val_loss: 32.3271 - val_mape: 19.0554 - learning_rate: 0.0015
# Epoch 97/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.5957 - mape: 18.8885 - val_loss: 33.1665 - val_mape: 18.9080 - learning_rate: 0.0015
# Epoch 98/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.8589 - mape: 18.7568 - val_loss: 30.8162 - val_mape: 18.4893 - learning_rate: 0.0015
# Epoch 99/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32.5558 - mape: 19.2266 - val_loss: 31.0020 - val_mape: 18.6752 - learning_rate: 0.0015
# Epoch 100/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.0429 - mape: 19.0243 - val_loss: 31.2439 - val_mape: 18.7295 - learning_rate: 7.5000e-04
# Epoch 101/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.6175 - mape: 19.2241 - val_loss: 30.6370 - val_mape: 18.5548 - learning_rate: 7.5000e-04
# Epoch 102/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.0941 - mape: 18.8005 - val_loss: 31.3013 - val_mape: 18.8049 - learning_rate: 7.5000e-04
# Epoch 103/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.0873 - mape: 18.9202 - val_loss: 30.6165 - val_mape: 18.8962 - learning_rate: 7.5000e-04
# Epoch 104/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.6339 - mape: 18.5449 - val_loss: 31.1114 - val_mape: 18.8855 - learning_rate: 7.5000e-04
# Epoch 105/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.3795 - mape: 18.3410 - val_loss: 30.3391 - val_mape: 19.1748 - learning_rate: 7.5000e-04
# Epoch 106/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.5509 - mape: 18.4141 - val_loss: 32.2332 - val_mape: 19.1235 - learning_rate: 7.5000e-04
# Epoch 107/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.3264 - mape: 19.4504 - val_loss: 32.9425 - val_mape: 19.2160 - learning_rate: 7.5000e-04
# Epoch 108/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.6019 - mape: 18.8397 - val_loss: 33.4481 - val_mape: 19.3549 - learning_rate: 7.5000e-04
# Epoch 109/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.1226 - mape: 19.1744 - val_loss: 31.2583 - val_mape: 18.8074 - learning_rate: 7.5000e-04
# Epoch 110/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.1950 - mape: 18.3193 - val_loss: 31.7187 - val_mape: 18.8355 - learning_rate: 7.5000e-04
# Epoch 111/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.8072 - mape: 19.9278 - val_loss: 32.5796 - val_mape: 19.4257 - learning_rate: 7.5000e-04
# Epoch 112/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.6592 - mape: 19.8101 - val_loss: 31.1723 - val_mape: 18.8961 - learning_rate: 7.5000e-04
# Epoch 113/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.9499 - mape: 18.8836 - val_loss: 30.9878 - val_mape: 18.8234 - learning_rate: 7.5000e-04
# Epoch 114/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.8999 - mape: 18.5737 - val_loss: 31.6526 - val_mape: 19.0422 - learning_rate: 7.5000e-04
# Epoch 115/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 29.6357 - mape: 18.6946 - val_loss: 29.9940 - val_mape: 18.3622 - learning_rate: 7.5000e-04
# Epoch 116/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8035 - mape: 19.0231 - val_loss: 30.1399 - val_mape: 19.3891 - learning_rate: 7.5000e-04
# Epoch 117/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 29.8846 - mape: 18.6119 - val_loss: 31.2656 - val_mape: 18.9374 - learning_rate: 7.5000e-04
# Epoch 118/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.2114 - mape: 18.9622 - val_loss: 31.6310 - val_mape: 18.8442 - learning_rate: 7.5000e-04
# Epoch 119/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.8860 - mape: 18.4696 - val_loss: 31.7149 - val_mape: 18.8163 - learning_rate: 7.5000e-04
# Epoch 120/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.5181 - mape: 18.8892 - val_loss: 31.1904 - val_mape: 18.4977 - learning_rate: 7.5000e-04
# Epoch 121/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.4078 - mape: 17.8469 - val_loss: 30.7755 - val_mape: 18.4859 - learning_rate: 7.5000e-04
# Epoch 122/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.4425 - mape: 18.4717 - val_loss: 31.8759 - val_mape: 18.9907 - learning_rate: 7.5000e-04
# Epoch 123/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30.6287 - mape: 19.1864 - val_loss: 31.8347 - val_mape: 19.0072 - learning_rate: 7.5000e-04
# Epoch 124/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.6896 - mape: 18.3241 - val_loss: 31.1753 - val_mape: 18.7927 - learning_rate: 7.5000e-04
# Epoch 125/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.6260 - mape: 18.8158 - val_loss: 31.9544 - val_mape: 18.8046 - learning_rate: 7.5000e-04
# Epoch 126/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 29.3001 - mape: 18.2385 - val_loss: 30.1850 - val_mape: 18.6597 - learning_rate: 7.5000e-04
# Epoch 127/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.4044 - mape: 18.4930 - val_loss: 32.5241 - val_mape: 18.9453 - learning_rate: 7.5000e-04
# Epoch 128/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.3509 - mape: 18.2348 - val_loss: 32.9583 - val_mape: 19.3689 - learning_rate: 7.5000e-04
# Epoch 129/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.0413 - mape: 18.7104 - val_loss: 30.2305 - val_mape: 18.8380 - learning_rate: 7.5000e-04
# Epoch 130/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.7933 - mape: 18.3901 - val_loss: 30.6883 - val_mape: 19.2724 - learning_rate: 7.5000e-04
# Epoch 131/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.7416 - mape: 19.0039 - val_loss: 29.8730 - val_mape: 18.5848 - learning_rate: 7.5000e-04
# Epoch 132/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.7758 - mape: 18.4751 - val_loss: 32.4812 - val_mape: 18.9750 - learning_rate: 7.5000e-04
# Epoch 133/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.9227 - mape: 17.5239 - val_loss: 31.7996 - val_mape: 19.1166 - learning_rate: 7.5000e-04
# Epoch 134/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.5048 - mape: 19.1778 - val_loss: 31.0569 - val_mape: 18.8138 - learning_rate: 7.5000e-04
# Epoch 135/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.6751 - mape: 19.1191 - val_loss: 30.6935 - val_mape: 18.4483 - learning_rate: 7.5000e-04
# Epoch 136/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.2438 - mape: 18.8533 - val_loss: 31.0885 - val_mape: 18.5319 - learning_rate: 7.5000e-04
# Epoch 137/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.8316 - mape: 18.8827 - val_loss: 31.4032 - val_mape: 18.8731 - learning_rate: 7.5000e-04
# Epoch 138/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 30.1850 - mape: 17.9982 - val_loss: 30.8338 - val_mape: 18.2375 - learning_rate: 7.5000e-04
# Epoch 139/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.7037 - mape: 18.6269 - val_loss: 30.8896 - val_mape: 18.7109 - learning_rate: 7.5000e-04
# Epoch 140/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.0158 - mape: 18.4433 - val_loss: 31.5795 - val_mape: 18.9048 - learning_rate: 7.5000e-04
# Epoch 141/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1992 - mape: 18.8501 - val_loss: 30.4611 - val_mape: 18.4784 - learning_rate: 7.5000e-04
# Epoch 142/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.6375 - mape: 19.1583 - val_loss: 31.2336 - val_mape: 18.5693 - learning_rate: 7.5000e-04
# Epoch 143/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.4727 - mape: 19.0971 - val_loss: 31.1654 - val_mape: 18.7238 - learning_rate: 7.5000e-04
# Epoch 144/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.4348 - mape: 17.4873 - val_loss: 33.4241 - val_mape: 19.4224 - learning_rate: 7.5000e-04
# Epoch 145/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.5433 - mape: 17.9569 - val_loss: 33.0615 - val_mape: 19.3417 - learning_rate: 7.5000e-04
# Epoch 146/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.4256 - mape: 18.7035 - val_loss: 32.6600 - val_mape: 19.2343 - learning_rate: 7.5000e-04
# Epoch 147/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.5294 - mape: 18.4468 - val_loss: 30.5228 - val_mape: 18.6786 - learning_rate: 7.5000e-04
# Epoch 148/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0591 - mape: 18.3234 - val_loss: 31.1177 - val_mape: 18.6823 - learning_rate: 7.5000e-04
# Epoch 149/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.9130 - mape: 19.3846 - val_loss: 31.0999 - val_mape: 18.6416 - learning_rate: 7.5000e-04
# Epoch 150/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.7102 - mape: 17.9691 - val_loss: 30.3299 - val_mape: 18.3421 - learning_rate: 3.7500e-04
# Epoch 151/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28.4405 - mape: 17.7926 - val_loss: 32.7260 - val_mape: 19.1266 - learning_rate: 3.7500e-04
# Epoch 152/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.4076 - mape: 18.4382 - val_loss: 30.6160 - val_mape: 18.4518 - learning_rate: 3.7500e-04
# Epoch 153/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.5239 - mape: 18.1962 - val_loss: 30.5943 - val_mape: 18.6267 - learning_rate: 3.7500e-04

# %%
# Saving the trained Model
model.save("python_model_Croissant.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making Predictions and Evaluating the Model
def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# MAPE on the Training Data: 17.31%
# MAPE on the Validation Data: 18.23%

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='Training MAPE')
plt.plot(history.history['val_mape'], label='Validation MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_predictions(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['actual'], label='Actual Values', color='red')
    plt.plot(data['prediction'], label='Predicted Values', color='blue')
    plt.title(title)
    plt.xlabel('Zeit')
    plt.ylabel('Umsatz')
    plt.legend()
    plt.show()

# Ensure that training_predictions, validation_predictions, training_labels, and validation_labels are numpy arrays
training_predictions = np.array(training_predictions).flatten()
validation_predictions = np.array(validation_predictions).flatten()
training_labels = np.array(training_labels).flatten()
validation_labels = np.array(validation_labels).flatten()

# print the type of the predictions
print(type(training_predictions))
print(type(validation_predictions))

# Create DataFrames with 1-dimensional arrays
data_train = pd.DataFrame({'prediction': training_predictions, 'actual': training_labels})
data_validation = pd.DataFrame({'prediction': validation_predictions, 'actual': validation_labels})

# Plot predictions
plot_predictions(data_train.head(100), 'Predicted and Actual Values for the Training Data')
plot_predictions(data_validation.head(100), 'Predicted and Actual Values for the Validation Data')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ***VORHERSAGE TESTZEITRAUM***

# %%
test_predictions = model.predict(test_features)
#print("Predictions for test data:", test_predictions[:5])  # Display first 5 predictions
# Größe des Arrays anzeigen
print("Größe des Arrays (shape):", test_predictions.shape)
test_predictions = pd.DataFrame(test_predictions)
test_predictions
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Größe des Arrays (shape): (355, 1)
#               0
# 0    265.328217
# 1    285.432343
# 2    285.432343
# 3    351.021362
# 4    306.709656
# ..          ...
# 350  257.193695
# 351  327.352600
# 352  307.955627
# 353  236.331406
# 354  245.925583
#
# [355 rows x 1 columns]

# %%
data_test = pd.read_csv("../../../0_DataPreparation/00_data/data_with_lag/Testdaten_with_lag.csv")
data_test = data_test[data_test["Warengruppe_3"] == 1]
data_test
# Out:
#            id       Datum  Warengruppe_1  Warengruppe_2  Warengruppe_3  \
# 710   1808013  2018-08-01              0              0              1
# 711   1808023  2018-08-02              0              0              1
# 712   1808033  2018-08-03              0              0              1
# 713   1808043  2018-08-04              0              0              1
# 714   1808053  2018-08-05              0              0              1
# ...       ...         ...            ...            ...            ...
# 1060  1907263  2019-07-26              0              0              1
# 1061  1907273  2019-07-27              0              0              1
# 1062  1907283  2019-07-28              0              0              1
# 1063  1907293  2019-07-29              0              0              1
# 1064  1907303  2019-07-30              0              0              1
#
#       Warengruppe_4  Warengruppe_5  Warengruppe_6  Temp_Very_Cold_current  \
# 710               0              0              0                       0
# 711               0              0              0                       0
# 712               0              0              0                       0
# 713               0              0              0                       0
# 714               0              0              0                       0
# ...             ...            ...            ...                     ...
# 1060              0              0              0                       0
# 1061              0              0              0                       0
# 1062              0              0              0                       0
# 1063              0              0              0                       0
# 1064              0              0              0                       0
#
#       Temp_Very_Cold_prev  ...  zwischen_den_jahren_next  \
# 710                   0.0  ...                       0.0
# 711                   0.0  ...                       0.0
# 712                   0.0  ...                       0.0
# 713                   0.0  ...                       0.0
# 714                   0.0  ...                       0.0
# ...                   ...  ...                       ...
# 1060                  0.0  ...                       0.0
# 1061                  0.0  ...                       0.0
# 1062                  0.0  ...                       0.0
# 1063                  0.0  ...                       0.0
# 1064                  0.0  ...                       0.0
#
#       Number_of_ships_scaled_current  Number_of_ships_scaled_prev  \
# 710                              0.0                          0.2
# 711                              0.0                          0.0
# 712                              0.0                          0.0
# 713                              0.2                          0.0
# 714                              0.0                          0.2
# ...                              ...                          ...
# 1060                             0.0                          0.2
# 1061                             0.6                          0.0
# 1062                             0.4                          0.6
# 1063                             0.2                          0.4
# 1064                             0.2                          0.2
#
#       Number_of_ships_scaled_next  Cloud_ok_current  Cloud_ok_prev  \
# 710                           0.0                 1            0.0
# 711                           0.0                 1            1.0
# 712                           0.2                 1            1.0
# 713                           0.0                 1            1.0
# 714                           0.0                 0            1.0
# ...                           ...               ...            ...
# 1060                          0.6                 1            0.0
# 1061                          0.4                 1            1.0
# 1062                          0.2                 1            1.0
# 1063                          0.2                 0            1.0
# 1064                          0.0                 0            0.0
#
#       Cloud_ok_next  Wind_ok_current  Wind_ok_prev  Wind_ok_next
# 710             1.0                1           1.0           1.0
# 711             1.0                1           1.0           1.0
# 712             1.0                1           1.0           1.0
# 713             0.0                1           1.0           1.0
# 714             1.0                1           1.0           1.0
# ...             ...              ...           ...           ...
# 1060            1.0                1           1.0           0.0
# 1061            1.0                0           1.0           1.0
# 1062            0.0                1           0.0           1.0
# 1063            0.0                1           1.0           1.0
# 1064            1.0                1           1.0           1.0
#
# [355 rows x 176 columns]

# %%
# Erstelle Ziel csv Datei

predictions_df = pd.DataFrame({
    'id': data_test['id'].values,
    'Umsatz': test_predictions[0].values
}).reset_index(drop=True)

# Save to a CSV file
#output_csv_path = "/workspaces/bakery_sales_prediction/3_Model/02_Franz/V3_lag/Umsatzvorhersage_Croissant_Hochladeformat.csv"

predictions_df.to_csv('Croissant_Umsatzvorhersage.csv', index=False)
print(f"CSV Datei erstellt")
# Out:
# CSV Datei erstellt
