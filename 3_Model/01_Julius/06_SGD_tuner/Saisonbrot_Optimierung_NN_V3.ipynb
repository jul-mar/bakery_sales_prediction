# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, AdamW
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

# %%
# Define the file paths
subdirectory = "pickle_data_Saisonbrot"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())
# Out:
# Loaded Training features dimensions: (236, 24)
# Loaded Validation features dimensions: (56, 24)
# Loaded Test features dimensions: (56, 24)
#
# Loaded Training labels dimensions: (236, 1)
# Loaded Validation labels dimensions: (56, 1)
#
# First few rows of loaded training features:
#       Temp_Cold_current  Temp_Mild_current  Cloud_Clear_current  \
# 9042                  0                  1                    0
# 9043                  0                  1                    0
# 9044                  0                  1                    0
# 9045                  0                  1                    0
# 9046                  0                  1                    0
#
#       Cloud_Cloudy_current  Weather_Moderate_current  Samstag_current  \
# 9042                     0                         0                0
# 9043                     1                         0                0
# 9044                     0                         0                1
# 9045                     1                         0                0
# 9046                     1                         0                0
#
#       Sonntag_current  VPI_current  Number_of_ships_scaled_current  \
# 9042                0        0.026                             0.0
# 9043                0        0.026                             0.0
# 9044                0        0.026                             0.0
# 9045                1        0.026                             0.0
# 9046                0        0.026                             0.0
#
#       Heimspiel_current  ...  wetter_sehr_schlecht_current  Monat_1_current  \
# 9042                  0  ...                             0                0
# 9043                  0  ...                             0                0
# 9044                  0  ...                             0                0
# 9045                  0  ...                             0                0
# 9046                  0  ...                             0                0
#
#       Monat_11_current  Monat_10_current  Monat_12_current  \
# 9042                 0                 1                 0
# 9043                 0                 1                 0
# 9044                 0                 1                 0
# 9045                 0                 1                 0
# 9046                 0                 1                 0
#
#       zwischen_den_jahren_current  Winter_next  Weather_Severe_next  \
# 9042                            0          0.0                  0.0
# 9043                            0          0.0                  0.0
# 9044                            0          0.0                  0.0
# 9045                            0          0.0                  0.0
# 9046                            0          0.0                  0.0
#
#       Monat_11_next  Temp_Cold_prev
# 9042            0.0             0.0
# 9043            0.0             0.0
# 9044            0.0             0.0
# 9045            0.0             0.0
# 9046            0.0             0.0
#
# [5 rows x 24 columns]
#
# First few rows of loaded training labels:
#          Umsatz
# 9042  41.813038
# 9043  16.410876
# 9044  18.574458
# 9045  24.640084
# 9046  43.515366

# %%
#Defining the Neural Network
#Now, let's define our neural network. We are using a Sequential model definition from Keras with batch normalization and dense layers.

model = Sequential([
    InputLayer(shape=(training_features.shape[1], )),
    Dropout(0.15),
    Dense(30, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.1)),
    Dropout(0.15),
    Dense(20, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.1)),

    Dense(1)
])

model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout_18 (Dropout)            │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 30)             │           750 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,391 (5.43 KB)
#  Trainable params: 1,391 (5.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# SGD with optimized parameters
optimizer = SGD(
    #learning_rate=0.003, durch den lr_scheduler geregelt
    momentum=0.9,    # Add momentum to help escape local minima
    nesterov=True,   # Use Nesterov momentum for better convergence
)

model.compile(
    loss="huber",    # More robust to outliers
    optimizer=optimizer,
    metrics=['mape']
)

# Custom learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.5
    epochs_drop = 50.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return max(lr, 1e-5)  # Don't let LR get too small

history = model.fit(
    training_features, 
    training_labels, 
    epochs=500,
    batch_size=8,   # Smaller batch size works better with SGD
    verbose=1,
    validation_data=(validation_features, validation_labels),
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True,
            mode='min'
        ),
        LearningRateScheduler(lr_schedule),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_loss',
            save_best_only=True,
            mode='min'
        )
    ]
)
# Out:
# Epoch 1/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 78.4282 - mape: 100.7503 - val_loss: 74.2103 - val_mape: 97.9860 - learning_rate: 0.0010
# Epoch 2/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 71.7230 - mape: 97.1110 - val_loss: 69.0144 - val_mape: 89.4776 - learning_rate: 0.0010
# Epoch 3/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 65.7035 - mape: 84.1420 - val_loss: 35.2345 - val_mape: 42.8594 - learning_rate: 0.0010
# Epoch 4/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.0294 - mape: 43.6904 - val_loss: 26.3848 - val_mape: 43.0519 - learning_rate: 0.0010
# Epoch 5/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.9819 - mape: 43.0114 - val_loss: 24.7945 - val_mape: 43.7803 - learning_rate: 0.0010
# Epoch 6/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 29.5451 - mape: 44.0234 - val_loss: 23.3350 - val_mape: 37.8756 - learning_rate: 0.0010
# Epoch 7/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.9463 - mape: 41.4855 - val_loss: 24.3474 - val_mape: 47.7852 - learning_rate: 0.0010
# Epoch 8/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.0434 - mape: 39.8005 - val_loss: 24.4786 - val_mape: 36.6045 - learning_rate: 0.0010
# Epoch 9/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.5701 - mape: 32.4852 - val_loss: 22.6259 - val_mape: 45.8468 - learning_rate: 0.0010
# Epoch 10/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.6109 - mape: 37.8888 - val_loss: 22.4015 - val_mape: 46.4759 - learning_rate: 0.0010
# Epoch 11/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.6903 - mape: 37.4172 - val_loss: 21.9528 - val_mape: 45.2105 - learning_rate: 0.0010
# Epoch 12/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.2981 - mape: 39.5601 - val_loss: 22.7018 - val_mape: 49.9388 - learning_rate: 0.0010
# Epoch 13/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.6423 - mape: 43.4343 - val_loss: 21.0333 - val_mape: 44.0975 - learning_rate: 0.0010
# Epoch 14/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.4310 - mape: 38.4007 - val_loss: 20.2105 - val_mape: 36.4210 - learning_rate: 0.0010
# Epoch 15/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.2002 - mape: 34.5327 - val_loss: 20.4608 - val_mape: 38.2407 - learning_rate: 0.0010
# Epoch 16/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.1342 - mape: 32.8106 - val_loss: 21.0012 - val_mape: 42.2788 - learning_rate: 0.0010
# Epoch 17/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.1782 - mape: 34.8403 - val_loss: 20.2133 - val_mape: 44.1063 - learning_rate: 0.0010
# Epoch 18/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.5354 - mape: 38.7942 - val_loss: 20.4388 - val_mape: 46.1356 - learning_rate: 0.0010
# Epoch 19/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.1679 - mape: 33.4513 - val_loss: 19.9017 - val_mape: 45.1979 - learning_rate: 0.0010
# Epoch 20/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.0419 - mape: 33.1164 - val_loss: 19.1885 - val_mape: 42.9111 - learning_rate: 0.0010
# Epoch 21/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.1688 - mape: 34.9240 - val_loss: 18.5799 - val_mape: 39.8643 - learning_rate: 0.0010
# Epoch 22/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.2686 - mape: 42.5917 - val_loss: 19.0045 - val_mape: 39.2883 - learning_rate: 0.0010
# Epoch 23/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.8999 - mape: 31.7912 - val_loss: 19.4244 - val_mape: 43.7478 - learning_rate: 0.0010
# Epoch 24/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.0899 - mape: 38.5644 - val_loss: 18.4305 - val_mape: 40.0641 - learning_rate: 0.0010
# Epoch 25/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.0154 - mape: 31.4104 - val_loss: 18.0454 - val_mape: 38.6253 - learning_rate: 0.0010
# Epoch 26/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 20.7954 - mape: 34.1754 - val_loss: 18.2187 - val_mape: 41.2799 - learning_rate: 0.0010
# Epoch 27/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.5061 - mape: 34.6430 - val_loss: 18.9757 - val_mape: 42.9391 - learning_rate: 0.0010
# Epoch 28/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.5094 - mape: 35.9892 - val_loss: 18.5433 - val_mape: 38.5540 - learning_rate: 0.0010
# Epoch 29/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.0160 - mape: 34.5335 - val_loss: 17.8230 - val_mape: 37.0428 - learning_rate: 0.0010
# Epoch 30/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.7387 - mape: 40.4270 - val_loss: 18.7634 - val_mape: 35.0980 - learning_rate: 0.0010
# Epoch 31/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.8123 - mape: 36.0973 - val_loss: 18.4709 - val_mape: 38.0150 - learning_rate: 0.0010
# Epoch 32/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.1323 - mape: 30.9287 - val_loss: 18.2890 - val_mape: 38.8287 - learning_rate: 0.0010
# Epoch 33/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.9453 - mape: 34.7394 - val_loss: 19.9311 - val_mape: 34.2080 - learning_rate: 0.0010
# Epoch 34/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6708 - mape: 39.9490 - val_loss: 18.7939 - val_mape: 35.9955 - learning_rate: 0.0010
# Epoch 35/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.0451 - mape: 32.7478 - val_loss: 17.4592 - val_mape: 37.7753 - learning_rate: 0.0010
# Epoch 36/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.3521 - mape: 39.4123 - val_loss: 19.0202 - val_mape: 36.1192 - learning_rate: 0.0010
# Epoch 37/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.0423 - mape: 31.3556 - val_loss: 18.0749 - val_mape: 42.6576 - learning_rate: 0.0010
# Epoch 38/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.0892 - mape: 35.5688 - val_loss: 18.3054 - val_mape: 40.0587 - learning_rate: 0.0010
# Epoch 39/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.2824 - mape: 33.2301 - val_loss: 18.4207 - val_mape: 35.5564 - learning_rate: 0.0010
# Epoch 40/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6337 - mape: 35.4787 - val_loss: 19.2977 - val_mape: 35.3622 - learning_rate: 0.0010
# Epoch 41/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.4110 - mape: 36.1965 - val_loss: 19.0139 - val_mape: 38.6011 - learning_rate: 0.0010
# Epoch 42/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.0424 - mape: 37.3828 - val_loss: 17.9809 - val_mape: 37.0055 - learning_rate: 0.0010
# Epoch 43/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.6501 - mape: 33.6724 - val_loss: 19.6806 - val_mape: 38.4112 - learning_rate: 0.0010
# Epoch 44/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.3800 - mape: 31.0127 - val_loss: 17.8097 - val_mape: 37.2973 - learning_rate: 0.0010
# Epoch 45/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.8350 - mape: 31.9156 - val_loss: 16.7728 - val_mape: 35.9051 - learning_rate: 0.0010
# Epoch 46/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.8108 - mape: 33.9181 - val_loss: 17.4639 - val_mape: 35.5274 - learning_rate: 0.0010
# Epoch 47/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.1392 - mape: 29.7801 - val_loss: 19.7856 - val_mape: 49.1419 - learning_rate: 0.0010
# Epoch 48/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.9736 - mape: 36.2209 - val_loss: 17.2473 - val_mape: 35.9253 - learning_rate: 0.0010
# Epoch 49/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.4586 - mape: 35.6577 - val_loss: 18.7604 - val_mape: 37.3377 - learning_rate: 0.0010
# Epoch 50/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.5279 - mape: 29.5719 - val_loss: 17.6484 - val_mape: 39.0374 - learning_rate: 5.0000e-04
# Epoch 51/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.7334 - mape: 33.1907 - val_loss: 18.9066 - val_mape: 36.6324 - learning_rate: 5.0000e-04
# Epoch 52/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.5108 - mape: 33.2135 - val_loss: 18.4533 - val_mape: 43.6525 - learning_rate: 5.0000e-04
# Epoch 53/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.3931 - mape: 30.8514 - val_loss: 17.6456 - val_mape: 40.4113 - learning_rate: 5.0000e-04
# Epoch 54/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.7916 - mape: 31.5851 - val_loss: 17.7973 - val_mape: 41.6558 - learning_rate: 5.0000e-04
# Epoch 55/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.6144 - mape: 39.3612 - val_loss: 19.4480 - val_mape: 36.5838 - learning_rate: 5.0000e-04

# %%
# Saving the trained Model
model.save("python_model_Saisonbrot.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making Predictions and Evaluating the Model
import numpy as np

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# MAPE on the Training Data: 31.51%
# MAPE on the Validation Data: 35.91%

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='Training MAPE')
plt.plot(history.history['val_mape'], label='Validation MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_predictions(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['actual'], label='Actual Values', color='red')
    plt.plot(data['prediction'], label='Predicted Values', color='blue')
    plt.title(title)
    plt.xlabel('Zeit')
    plt.ylabel('Umsatz')
    plt.legend()
    plt.show()

# Ensure that training_predictions, validation_predictions, training_labels, and validation_labels are numpy arrays
training_predictions = np.array(training_predictions).flatten()
validation_predictions = np.array(validation_predictions).flatten()
training_labels = np.array(training_labels).flatten()
validation_labels = np.array(validation_labels).flatten()

# print the type of the predictions
print(type(training_predictions))
print(type(validation_predictions))

# Create DataFrames with 1-dimensional arrays
data_train = pd.DataFrame({'prediction': training_predictions, 'actual': training_labels})
data_validation = pd.DataFrame({'prediction': validation_predictions, 'actual': validation_labels})

# Plot predictions
plot_predictions(data_train.head(100), 'Predicted and Actual Values for the Training Data')
plot_predictions(data_validation.head(100), 'Predicted and Actual Values for the Validation Data')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ***VORHERSAGE TESTZEITRAUM***

# %%
test_predictions = model.predict(test_features)
#print("Predictions for test data:", test_predictions[:5])  # Display first 5 predictions
# Größe des Arrays anzeigen
print("Größe des Arrays (shape):", test_predictions.shape)
test_predictions = pd.DataFrame(test_predictions)
test_predictions
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Größe des Arrays (shape): (56, 1)
#             0
# 0   38.907681
# 1   37.167587
# 2   59.877872
# 3   44.608414
# 4   41.665302
# 5   43.120010
# 6   49.139664
# 7   36.367081
# 8   43.120010
# 9   45.444569
# 10  34.295521
# 11  37.167587
# 12  37.167587
# 13  43.943619
# 14  50.091709
# 15  52.454540
# 16  60.777496
# 17  43.772594
# 18  44.555843
# 19  47.078106
# 20  47.078106
# 21  47.078106
# 22  47.739285
# 23  55.121841
# 24  43.772594
# 25  71.887665
# 26  71.887665
# 27  74.261330
# 28  71.887665
# 29  79.047089
# 30  86.903564
# 31  79.019287
# 32  76.495651
# 33  87.123825
# 34  90.574150
# 35  82.149742
# 36  74.229790
# 37  80.447113
# 38  79.019287
# 39  84.138031
# 40  82.306679
# 41  82.306679
# 42  82.306679
# 43  85.223930
# 44  86.903564
# 45  76.655090
# 46  82.306679
# 47  82.306679
# 48  82.306679
# 49  82.306679
# 50  78.172119
# 51  85.022682
# 52  80.048119
# 53  55.907703
# 54  46.886196
# 55  46.886196

# %%
data_test = pd.read_csv("../../../0_DataPreparation/00_data/data_with_lag/Testdaten_with_lag.csv")
data_test = data_test[data_test["Warengruppe_6"] == 1]
data_test
# Out:
#            id       Datum  Warengruppe_1  Warengruppe_2  Warengruppe_3  \
# 1774  1811016  2018-11-01              0              0              0
# 1775  1811026  2018-11-02              0              0              0
# 1776  1811036  2018-11-03              0              0              0
# 1777  1811046  2018-11-04              0              0              0
# 1778  1811056  2018-11-05              0              0              0
# 1779  1811066  2018-11-06              0              0              0
# 1780  1811076  2018-11-07              0              0              0
# 1781  1811086  2018-11-08              0              0              0
# 1782  1811096  2018-11-09              0              0              0
# 1783  1811106  2018-11-10              0              0              0
# 1784  1811116  2018-11-11              0              0              0
# 1785  1811126  2018-11-12              0              0              0
# 1786  1811136  2018-11-13              0              0              0
# 1787  1811146  2018-11-14              0              0              0
# 1788  1811156  2018-11-15              0              0              0
# 1789  1811166  2018-11-16              0              0              0
# 1790  1811176  2018-11-17              0              0              0
# 1791  1811186  2018-11-18              0              0              0
