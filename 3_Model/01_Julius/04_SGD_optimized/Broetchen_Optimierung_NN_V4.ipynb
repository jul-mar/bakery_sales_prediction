# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, AdamW
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
# Out:
# 2025-01-05 22:57:35.474814: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-05 22:57:35.486634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736114255.499116 1432935 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736114255.502752 1432935 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 22:57:35.517016: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define the file paths
subdirectory = "pickle_data_Broetchen"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())
# Out:
# Loaded Training features dimensions: (1462, 24)
# Loaded Validation features dimensions: (357, 24)
# Loaded Test features dimensions: (355, 24)
#
# Loaded Training labels dimensions: (1462, 1)
# Loaded Validation labels dimensions: (357, 1)
#
# First few rows of loaded training features:
#       Temp_Cold_current  Temp_Mild_current  Temp_Warm_current  \
# 1819                  0                  1                  0
# 1820                  0                  1                  0
# 1821                  0                  0                  1
# 1822                  0                  1                  0
# 1823                  0                  1                  0
#
#       Temp_Hot_current  Cloud_ok_current  Cloud_Cloudy_current  \
# 1819                 0                 0                     1
# 1820                 0                 1                     0
# 1821                 0                 0                     1
# 1822                 0                 0                     1
# 1823                 0                 1                     0
#
#       KielerWoche_current  Samstag_current  Sonntag_current  VPI_current  ...  \
# 1819                    0                0                0        0.052  ...
# 1820                    0                0                0        0.052  ...
# 1821                    0                0                0        0.052  ...
# 1822                    0                0                0        0.052  ...
# 1823                    0                0                0        0.052  ...
#
#       Ostertag_current  Silvester_current  Werktag_current  Sommer_current  \
# 1819                 0                  0                1               1
# 1820                 0                  0                1               1
# 1821                 0                  0                1               1
# 1822                 0                  0                1               1
# 1823                 0                  0                1               1
#
#       Winter_current  wetter_sehr_schlecht_current  wetter_sehr_schön_current  \
# 1819               0                             0                          0
# 1820               0                             0                          0
# 1821               0                             1                          0
# 1822               0                             0                          0
# 1823               0                             0                          0
#
#       Monat_7_current  Monat_1_current  is_holiday_next
# 1819                1                0              1.0
# 1820                1                0              1.0
# 1821                1                0              1.0
# 1822                1                0              1.0
# 1823                1                0              1.0
#
# [5 rows x 24 columns]
#
# First few rows of loaded training labels:
#           Umsatz
# 1819  535.856285
# 1820  546.780787
# 1821  427.343259
# 1822  454.859641
# 1823  492.818804

# %%
#Defining the Neural Network
#Now, let's define our neural network. We are using a Sequential model definition from Keras with batch normalization and dense layers.

model = Sequential([
    InputLayer(shape=(training_features.shape[1], )),
    Dropout(0.1),
    Dense(50, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.01)),
    Dropout(0.15),
    Dense(25, activation='relu', kernel_initializer="he_normal", kernel_regularizer=l2(0.01)),

    Dense(1)
])

model.summary()
# Out:
# I0000 00:00:1736114256.964622 1432935 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │         1,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,551 (9.96 KB)
#  Trainable params: 2,551 (9.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# SGD with optimized parameters
optimizer = SGD(
    #learning_rate=0.003, durch den lr_scheduler geregelt
    momentum=0.9,    # Add momentum to help escape local minima
    nesterov=True,   # Use Nesterov momentum for better convergence
)

model.compile(
    loss="huber",    # More robust to outliers
    optimizer=optimizer,
    metrics=['mape']
)

# Custom learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.5
    epochs_drop = 50.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return max(lr, 1e-5)  # Don't let LR get too small

history = model.fit(
    training_features, 
    training_labels, 
    epochs=500,
    batch_size=8,   # Smaller batch size works better with SGD
    verbose=1,
    validation_data=(validation_features, validation_labels),
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            mode='min'
        ),
        LearningRateScheduler(lr_schedule),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_loss',
            save_best_only=True,
            mode='min'
        )
    ]
)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736114259.222513 1437388 service.cc:148] XLA service 0x7ff584004ef0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736114259.222613 1437388 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-01-05 22:57:39.242639: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736114259.316794 1437388 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  45/183 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 410.5134 - mape: 99.6912
# I0000 00:00:1736114260.814563 1437388 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 342.4384 - mape: 83.3781 - val_loss: 50.3295 - val_mape: 14.6568 - learning_rate: 0.0010
# Epoch 2/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 77.9955 - mape: 18.6571 - val_loss: 71.4143 - val_mape: 21.9745 - learning_rate: 0.0010
# Epoch 3/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 72.8733 - mape: 17.4534 - val_loss: 56.3516 - val_mape: 16.8197 - learning_rate: 0.0010
# Epoch 4/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 72.8337 - mape: 17.5167 - val_loss: 44.9198 - val_mape: 12.3460 - learning_rate: 0.0010
# Epoch 5/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 68.3216 - mape: 15.6441 - val_loss: 45.4496 - val_mape: 12.6623 - learning_rate: 0.0010
# Epoch 6/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 68.2946 - mape: 15.9869 - val_loss: 46.0920 - val_mape: 13.3256 - learning_rate: 0.0010
# Epoch 7/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 66.5385 - mape: 15.5932 - val_loss: 44.2514 - val_mape: 12.0165 - learning_rate: 0.0010
# Epoch 8/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 65.6437 - mape: 15.8523 - val_loss: 46.2097 - val_mape: 12.1382 - learning_rate: 0.0010
# Epoch 9/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.0032 - mape: 15.1181 - val_loss: 44.7394 - val_mape: 11.9840 - learning_rate: 0.0010
# Epoch 10/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 65.1438 - mape: 15.4970 - val_loss: 48.6198 - val_mape: 13.2188 - learning_rate: 0.0010
# Epoch 11/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 64.6160 - mape: 15.0586 - val_loss: 52.9493 - val_mape: 12.8432 - learning_rate: 0.0010
# Epoch 12/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 65.7617 - mape: 15.8996 - val_loss: 47.4697 - val_mape: 12.3795 - learning_rate: 0.0010
# Epoch 13/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 63.0012 - mape: 14.9354 - val_loss: 49.2569 - val_mape: 12.5190 - learning_rate: 0.0010
# Epoch 14/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 65.7170 - mape: 15.5004 - val_loss: 49.0241 - val_mape: 14.2035 - learning_rate: 0.0010
# Epoch 15/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 66.0909 - mape: 15.8330 - val_loss: 45.7314 - val_mape: 12.3986 - learning_rate: 0.0010
# Epoch 16/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 63.6171 - mape: 15.2037 - val_loss: 44.2953 - val_mape: 11.9594 - learning_rate: 0.0010
# Epoch 17/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 63.2947 - mape: 14.9297 - val_loss: 45.5330 - val_mape: 11.6888 - learning_rate: 0.0010
# Epoch 18/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.4803 - mape: 15.1270 - val_loss: 45.2670 - val_mape: 12.0537 - learning_rate: 0.0010
# Epoch 19/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.7910 - mape: 15.1992 - val_loss: 46.5447 - val_mape: 12.9801 - learning_rate: 0.0010
# Epoch 20/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.2502 - mape: 15.0497 - val_loss: 45.4732 - val_mape: 11.6036 - learning_rate: 0.0010
# Epoch 21/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.4656 - mape: 14.9375 - val_loss: 43.3831 - val_mape: 11.4367 - learning_rate: 0.0010
# Epoch 22/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.2047 - mape: 15.5044 - val_loss: 49.1635 - val_mape: 12.2377 - learning_rate: 0.0010
# Epoch 23/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.6310 - mape: 15.1362 - val_loss: 45.0205 - val_mape: 12.6482 - learning_rate: 0.0010
# Epoch 24/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.1815 - mape: 15.6555 - val_loss: 52.3085 - val_mape: 12.9579 - learning_rate: 0.0010
# Epoch 25/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.7776 - mape: 15.6767 - val_loss: 45.9112 - val_mape: 12.0386 - learning_rate: 0.0010
# Epoch 26/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ -1s -7506us/step - loss: 63.3767 - mape: 14.6889 - val_loss: 46.6321 - val_mape: 14.0536 - learning_rate: 0.0010
# Epoch 27/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 63.8582 - mape: 15.1076 - val_loss: 45.1984 - val_mape: 12.5629 - learning_rate: 0.0010
# Epoch 28/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.8024 - mape: 14.9382 - val_loss: 42.6404 - val_mape: 11.3558 - learning_rate: 0.0010
# Epoch 29/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64.5109 - mape: 15.3001 - val_loss: 51.0841 - val_mape: 12.4962 - learning_rate: 0.0010
# Epoch 30/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 63.9923 - mape: 14.8242 - val_loss: 50.7333 - val_mape: 12.6855 - learning_rate: 0.0010
# Epoch 31/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.8788 - mape: 14.5398 - val_loss: 48.8851 - val_mape: 12.1324 - learning_rate: 0.0010
# Epoch 32/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.0456 - mape: 14.2147 - val_loss: 44.4050 - val_mape: 12.2782 - learning_rate: 0.0010
# Epoch 33/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 60.0328 - mape: 14.3833 - val_loss: 45.4116 - val_mape: 13.2350 - learning_rate: 0.0010
# Epoch 34/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 60.8961 - mape: 14.2474 - val_loss: 43.7136 - val_mape: 11.5388 - learning_rate: 0.0010
# Epoch 35/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.4404 - mape: 14.3250 - val_loss: 44.0293 - val_mape: 12.1539 - learning_rate: 0.0010
# Epoch 36/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.8093 - mape: 14.8564 - val_loss: 44.8975 - val_mape: 11.3326 - learning_rate: 0.0010
# Epoch 37/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58.5357 - mape: 13.8976 - val_loss: 47.5312 - val_mape: 11.9882 - learning_rate: 0.0010
# Epoch 38/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 60.1103 - mape: 14.3056 - val_loss: 50.2606 - val_mape: 15.1456 - learning_rate: 0.0010
# Epoch 39/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 60.6347 - mape: 14.4803 - val_loss: 50.6106 - val_mape: 12.3078 - learning_rate: 0.0010
# Epoch 40/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.0518 - mape: 14.2440 - val_loss: 51.1292 - val_mape: 15.0650 - learning_rate: 0.0010
# Epoch 41/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.1641 - mape: 14.5188 - val_loss: 44.1874 - val_mape: 11.7099 - learning_rate: 0.0010
# Epoch 42/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.5608 - mape: 14.3391 - val_loss: 45.5393 - val_mape: 13.1137 - learning_rate: 0.0010
# Epoch 43/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58.1275 - mape: 13.7984 - val_loss: 41.4774 - val_mape: 11.0759 - learning_rate: 0.0010
# Epoch 44/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 59.6620 - mape: 14.3028 - val_loss: 57.8204 - val_mape: 14.1728 - learning_rate: 0.0010
# Epoch 45/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58.8683 - mape: 13.6299 - val_loss: 62.6250 - val_mape: 14.7473 - learning_rate: 0.0010
# Epoch 46/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 59.7404 - mape: 13.8895 - val_loss: 46.6531 - val_mape: 12.2336 - learning_rate: 0.0010
# Epoch 47/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58.8146 - mape: 13.8697 - val_loss: 48.2327 - val_mape: 13.3009 - learning_rate: 0.0010
# Epoch 48/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 59.8618 - mape: 14.2472 - val_loss: 46.8241 - val_mape: 13.1125 - learning_rate: 0.0010
# Epoch 49/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 60.1492 - mape: 14.1098 - val_loss: 45.7536 - val_mape: 12.2777 - learning_rate: 0.0010
# Epoch 50/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 58.4959 - mape: 13.6530 - val_loss: 44.5441 - val_mape: 12.3343 - learning_rate: 5.0000e-04
# Epoch 51/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58.4325 - mape: 13.5165 - val_loss: 42.6906 - val_mape: 11.8770 - learning_rate: 5.0000e-04
# Epoch 52/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 57.5639 - mape: 13.1427 - val_loss: 43.6789 - val_mape: 12.2894 - learning_rate: 5.0000e-04
# Epoch 53/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 57.5219 - mape: 13.4924 - val_loss: 48.8708 - val_mape: 12.8147 - learning_rate: 5.0000e-04
# Epoch 54/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.0564 - mape: 13.4725 - val_loss: 44.1733 - val_mape: 12.6426 - learning_rate: 5.0000e-04
# Epoch 55/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 56.1494 - mape: 13.0280 - val_loss: 45.4420 - val_mape: 13.0988 - learning_rate: 5.0000e-04
# Epoch 56/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 55.8935 - mape: 13.3597 - val_loss: 50.0954 - val_mape: 13.1396 - learning_rate: 5.0000e-04
# Epoch 57/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.1792 - mape: 13.2656 - val_loss: 47.8358 - val_mape: 12.4580 - learning_rate: 5.0000e-04
# Epoch 58/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.4596 - mape: 13.6146 - val_loss: 44.2841 - val_mape: 12.1897 - learning_rate: 5.0000e-04
# Epoch 59/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 55.5582 - mape: 13.1254 - val_loss: 49.3742 - val_mape: 13.0674 - learning_rate: 5.0000e-04
# Epoch 60/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 57.2516 - mape: 13.3948 - val_loss: 45.7362 - val_mape: 12.3180 - learning_rate: 5.0000e-04
# Epoch 61/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.1118 - mape: 13.7632 - val_loss: 48.2970 - val_mape: 12.9013 - learning_rate: 5.0000e-04
# Epoch 62/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.7368 - mape: 13.7124 - val_loss: 47.0601 - val_mape: 12.3754 - learning_rate: 5.0000e-04
# Epoch 63/500
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.1222 - mape: 13.8617 - val_loss: 44.6870 - val_mape: 12.3421 - learning_rate: 5.0000e-04

# %%
# Saving the trained Model
model.save("python_model_Broetchen.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making Predictions and Evaluating the Model
import numpy as np

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# MAPE on the Training Data: 11.69%
# MAPE on the Validation Data: 11.08%

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='Training MAPE')
plt.plot(history.history['val_mape'], label='Validation MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_predictions(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['actual'], label='Actual Values', color='red')
    plt.plot(data['prediction'], label='Predicted Values', color='blue')
    plt.title(title)
    plt.xlabel('Zeit')
    plt.ylabel('Umsatz')
    plt.legend()
    plt.show()

# Ensure that training_predictions, validation_predictions, training_labels, and validation_labels are numpy arrays
training_predictions = np.array(training_predictions).flatten()
validation_predictions = np.array(validation_predictions).flatten()
training_labels = np.array(training_labels).flatten()
validation_labels = np.array(validation_labels).flatten()

# print the type of the predictions
print(type(training_predictions))
print(type(validation_predictions))

# Create DataFrames with 1-dimensional arrays
data_train = pd.DataFrame({'prediction': training_predictions, 'actual': training_labels})
data_validation = pd.DataFrame({'prediction': validation_predictions, 'actual': validation_labels})

# Plot predictions
plot_predictions(data_train.head(100), 'Predicted and Actual Values for the Training Data')
plot_predictions(data_validation.head(100), 'Predicted and Actual Values for the Validation Data')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ***VORHERSAGE TESTZEITRAUM***

# %%
test_predictions = model.predict(test_features)
#print("Predictions for test data:", test_predictions[:5])  # Display first 5 predictions
# Größe des Arrays anzeigen
print("Größe des Arrays (shape):", test_predictions.shape)
test_predictions = pd.DataFrame(test_predictions)
test_predictions
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Größe des Arrays (shape): (355, 1)
#               0
# 0    503.718750
# 1    517.772766
# 2    517.772766
# 3    657.581909
# 4    619.763977
# ..          ...
# 350  516.070374
# 351  626.934082
# 352  631.515320
# 353  528.326721
# 354  516.021057
#
# [355 rows x 1 columns]

# %%
data_test = pd.read_csv("../../../0_DataPreparation/00_data/data_with_lag/Testdaten_with_lag.csv")
data_test = data_test[data_test["Warengruppe_2"] == 1]
data_test
# Out:
#           id       Datum  Warengruppe_1  Warengruppe_2  Warengruppe_3  \
# 355  1808012  2018-08-01              0              1              0
# 356  1808022  2018-08-02              0              1              0
# 357  1808032  2018-08-03              0              1              0
# 358  1808042  2018-08-04              0              1              0
# 359  1808052  2018-08-05              0              1              0
# ..       ...         ...            ...            ...            ...
# 705  1907262  2019-07-26              0              1              0
# 706  1907272  2019-07-27              0              1              0
# 707  1907282  2019-07-28              0              1              0
# 708  1907292  2019-07-29              0              1              0
# 709  1907302  2019-07-30              0              1              0
#
#      Warengruppe_4  Warengruppe_5  Warengruppe_6  Temp_Very_Cold_current  \
# 355              0              0              0                       0
# 356              0              0              0                       0
# 357              0              0              0                       0
# 358              0              0              0                       0
# 359              0              0              0                       0
# ..             ...            ...            ...                     ...
# 705              0              0              0                       0
# 706              0              0              0                       0
# 707              0              0              0                       0
# 708              0              0              0                       0
# 709              0              0              0                       0
#
#      Temp_Very_Cold_prev  ...  zwischen_den_jahren_next  \
# 355                  0.0  ...                       0.0
# 356                  0.0  ...                       0.0
# 357                  0.0  ...                       0.0
# 358                  0.0  ...                       0.0
# 359                  0.0  ...                       0.0
# ..                   ...  ...                       ...
# 705                  0.0  ...                       0.0
# 706                  0.0  ...                       0.0
# 707                  0.0  ...                       0.0
# 708                  0.0  ...                       0.0
# 709                  0.0  ...                       0.0
#
#      Number_of_ships_scaled_current  Number_of_ships_scaled_prev  \
# 355                             0.0                          0.2
# 356                             0.0                          0.0
# 357                             0.0                          0.0
# 358                             0.2                          0.0
# 359                             0.0                          0.2
# ..                              ...                          ...
# 705                             0.0                          0.2
# 706                             0.6                          0.0
# 707                             0.4                          0.6
# 708                             0.2                          0.4
# 709                             0.2                          0.2
#
#      Number_of_ships_scaled_next  Cloud_ok_current  Cloud_ok_prev  \
# 355                          0.0                 1            0.0
# 356                          0.0                 1            1.0
# 357                          0.2                 1            1.0
# 358                          0.0                 1            1.0
# 359                          0.0                 0            1.0
# ..                           ...               ...            ...
# 705                          0.6                 1            0.0
# 706                          0.4                 1            1.0
# 707                          0.2                 1            1.0
# 708                          0.2                 0            1.0
# 709                          0.0                 0            0.0
#
#      Cloud_ok_next  Wind_ok_current  Wind_ok_prev  Wind_ok_next
# 355            1.0                1           1.0           1.0
# 356            1.0                1           1.0           1.0
# 357            1.0                1           1.0           1.0
# 358            0.0                1           1.0           1.0
# 359            1.0                1           1.0           1.0
# ..             ...              ...           ...           ...
# 705            1.0                1           1.0           0.0
# 706            1.0                0           1.0           1.0
# 707            0.0                1           0.0           1.0
# 708            0.0                1           1.0           1.0
# 709            1.0                1           1.0           1.0
#
# [355 rows x 176 columns]

# %%
# Erstelle Ziel csv Datei

predictions_df = pd.DataFrame({
    'id': data_test['id'].values,
    'Umsatz': test_predictions[0].values
}).reset_index(drop=True)

# Save to a CSV file
#output_csv_path = "/workspaces/bakery_sales_prediction/3_Model/02_Franz/V3_lag/Umsatzvorhersage_Broetchen_Hochladeformat.csv"

predictions_df.to_csv('Broetchen_Umsatzvorhersage.csv', index=False)
print(f"CSV Datei erstellt")
# Out:
# CSV Datei erstellt
