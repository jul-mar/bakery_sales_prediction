# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, AdamW
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
# Out:
# 2025-01-05 22:14:29.767014: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-05 22:14:29.779460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736111669.792408 1343962 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736111669.795862 1343962 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 22:14:29.809362: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define the file paths
subdirectory = "pickle_data_Konditorei"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())
# Out:
# Loaded Training features dimensions: (1409, 31)
# Loaded Validation features dimensions: (357, 31)
# Loaded Test features dimensions: (354, 31)
#
# Loaded Training labels dimensions: (1409, 1)
# Loaded Validation labels dimensions: (357, 1)
#
# First few rows of loaded training features:
#       Temp_Cold_current  Temp_Warm_current  Temp_Hot_current  \
# 5457                  0                  0                 0
# 5458                  0                  0                 0
# 5459                  0                  1                 0
# 5460                  0                  0                 0
# 5461                  0                  0                 0
#
#       Cloud_ok_current  Cloud_Cloudy_current  KielerWoche_current  \
# 5457                 0                     1                    0
# 5458                 1                     0                    0
# 5459                 0                     1                    0
# 5460                 0                     1                    0
# 5461                 1                     0                    0
#
#       Montag_current  Dienstag_current  Mittwoch_current  Donnerstag_current  \
# 5457               1                 0                 0                   0
# 5458               0                 1                 0                   0
# 5459               0                 0                 1                   0
# 5460               0                 0                 0                   1
# 5461               0                 0                 0                   0
#
#       ...  wetter_sehr_schlecht_current  wetter_sehr_schön_current  \
# 5457  ...                             0                          0
# 5458  ...                             0                          0
# 5459  ...                             1                          0
# 5460  ...                             0                          0
# 5461  ...                             0                          0
#
#       Monat_2_current  Monat_8_current  Monat_7_current  Monat_6_current  \
# 5457                0                0                1                0
# 5458                0                0                1                0
# 5459                0                0                1                0
# 5460                0                0                1                0
# 5461                0                0                1                0
#
#       Monat_12_current  Heimspiel_prev  Ostertag_prev  KielerWoche_next
# 5457                 0             0.0            0.0               0.0
# 5458                 0             0.0            0.0               0.0
# 5459                 0             0.0            0.0               0.0
# 5460                 0             0.0            0.0               0.0
# 5461                 0             0.0            0.0               0.0
#
# [5 rows x 31 columns]
#
# First few rows of loaded training labels:
#          Umsatz
# 5457  65.890169
# 5458  74.543917
# 5459  69.262728
# 5460  61.490175
# 5461  86.759861

# %%
#Defining the Neural Network

model = Sequential([
    InputLayer(shape=(training_features.shape[1], )),
    Dropout(0.2),
    Dense(50, activation='relu', kernel_initializer="he_normal"),
    # Dropout(0.2),
    Dense(25, activation='relu', kernel_initializer="he_normal"),

    Dense(1)
])

model.summary()
# Out:
# I0000 00:00:1736111671.236845 1343962 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1577 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 31)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,901 (11.33 KB)
#  Trainable params: 2,901 (11.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# SGD with optimized parameters
optimizer = SGD(
    #learning_rate=0.001, gesteuert durch den lr_scheduler
    momentum=0.9,    # Add momentum to help escape local minima
    nesterov=True,   # Use Nesterov momentum for better convergence
)

model.compile(
    loss="huber",    # More robust to outliers
    optimizer=optimizer,
    metrics=['mape']
)

# Custom learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.0001
    drop = 0.5
    epochs_drop = 50.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return max(lr, 1e-5)  # Don't let LR get too small

history = model.fit(
    training_features, 
    training_labels, 
    epochs=500,
    batch_size=16,   # Smaller batch size works better with SGD
    verbose=1,
    validation_data=(validation_features, validation_labels),
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            mode='min'
        ),
        LearningRateScheduler(lr_schedule),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_loss',
            save_best_only=True,
            mode='min'
        )
    ]
)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736111672.357085 1344061 service.cc:148] XLA service 0x7f7900008250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736111672.357129 1344061 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-01-05 22:14:32.370268: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736111672.418311 1344061 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 61/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90.0709 - mape: 99.8671
# I0000 00:00:1736111673.278421 1344061 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 89.4056 - mape: 99.8183 - val_loss: 85.4923 - val_mape: 99.3951 - learning_rate: 1.0000e-04
# Epoch 2/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 88.8222 - mape: 99.1098 - val_loss: 84.8212 - val_mape: 98.5450 - learning_rate: 1.0000e-04
# Epoch 3/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 86.5288 - mape: 98.1345 - val_loss: 83.8085 - val_mape: 97.2615 - learning_rate: 1.0000e-04
# Epoch 4/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.7497 - mape: 96.5501 - val_loss: 82.0634 - val_mape: 95.0470 - learning_rate: 1.0000e-04
# Epoch 5/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 81.9888 - mape: 93.8062 - val_loss: 78.6760 - val_mape: 90.7382 - learning_rate: 1.0000e-04
# Epoch 6/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 80.2136 - mape: 88.5953 - val_loss: 70.9063 - val_mape: 80.8457 - learning_rate: 1.0000e-04
# Epoch 7/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.2087 - mape: 75.1033 - val_loss: 48.0336 - val_mape: 51.8292 - learning_rate: 1.0000e-04
# Epoch 8/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.0184 - mape: 42.8689 - val_loss: 25.5189 - val_mape: 28.8327 - learning_rate: 1.0000e-04
# Epoch 9/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.4752 - mape: 31.5657 - val_loss: 23.7475 - val_mape: 27.3432 - learning_rate: 1.0000e-04
# Epoch 10/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.2901 - mape: 30.0936 - val_loss: 22.2705 - val_mape: 26.2030 - learning_rate: 1.0000e-04
# Epoch 11/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.8231 - mape: 29.1241 - val_loss: 21.1766 - val_mape: 25.3189 - learning_rate: 1.0000e-04
# Epoch 12/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.3925 - mape: 28.8841 - val_loss: 20.4327 - val_mape: 24.6647 - learning_rate: 1.0000e-04
# Epoch 13/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.4328 - mape: 26.7671 - val_loss: 19.9136 - val_mape: 24.1192 - learning_rate: 1.0000e-04
# Epoch 14/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.0449 - mape: 27.1732 - val_loss: 19.4765 - val_mape: 24.0593 - learning_rate: 1.0000e-04
# Epoch 15/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.0140 - mape: 25.5487 - val_loss: 19.2040 - val_mape: 23.7570 - learning_rate: 1.0000e-04
# Epoch 16/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.5452 - mape: 25.4302 - val_loss: 18.9691 - val_mape: 23.5809 - learning_rate: 1.0000e-04
# Epoch 17/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.8069 - mape: 23.3993 - val_loss: 18.7795 - val_mape: 23.6569 - learning_rate: 1.0000e-04
# Epoch 18/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.2980 - mape: 24.6968 - val_loss: 18.5992 - val_mape: 23.4333 - learning_rate: 1.0000e-04
# Epoch 19/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.4831 - mape: 24.1896 - val_loss: 18.4555 - val_mape: 23.3387 - learning_rate: 1.0000e-04
# Epoch 20/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.5989 - mape: 23.9572 - val_loss: 18.3256 - val_mape: 23.2687 - learning_rate: 1.0000e-04
# Epoch 21/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.0365 - mape: 24.1514 - val_loss: 18.2882 - val_mape: 23.0504 - learning_rate: 1.0000e-04
# Epoch 22/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.7863 - mape: 22.4772 - val_loss: 18.2350 - val_mape: 23.0573 - learning_rate: 1.0000e-04
# Epoch 23/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.6755 - mape: 22.8814 - val_loss: 18.2214 - val_mape: 23.1765 - learning_rate: 1.0000e-04
# Epoch 24/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 20.0212 - mape: 24.1050 - val_loss: 18.1469 - val_mape: 23.0205 - learning_rate: 1.0000e-04
# Epoch 25/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.4769 - mape: 23.5613 - val_loss: 18.1329 - val_mape: 22.7091 - learning_rate: 1.0000e-04
# Epoch 26/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.1261 - mape: 22.9488 - val_loss: 18.1740 - val_mape: 22.5671 - learning_rate: 1.0000e-04
# Epoch 27/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.0831 - mape: 22.8866 - val_loss: 18.1931 - val_mape: 23.0664 - learning_rate: 1.0000e-04
# Epoch 28/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.1000 - mape: 22.1900 - val_loss: 18.1202 - val_mape: 22.7304 - learning_rate: 1.0000e-04
# Epoch 29/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3228 - mape: 22.4739 - val_loss: 18.1124 - val_mape: 22.8502 - learning_rate: 1.0000e-04
# Epoch 30/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.9212 - mape: 22.9554 - val_loss: 18.1493 - val_mape: 22.7348 - learning_rate: 1.0000e-04
# Epoch 31/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.9087 - mape: 21.9100 - val_loss: 18.3683 - val_mape: 22.5249 - learning_rate: 1.0000e-04
# Epoch 32/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.4178 - mape: 22.1171 - val_loss: 18.2638 - val_mape: 22.5240 - learning_rate: 1.0000e-04
# Epoch 33/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.4475 - mape: 22.2303 - val_loss: 18.1069 - val_mape: 22.4876 - learning_rate: 1.0000e-04
# Epoch 34/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.6836 - mape: 22.1247 - val_loss: 18.1348 - val_mape: 22.3950 - learning_rate: 1.0000e-04
# Epoch 35/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 18.8519 - mape: 21.4884 - val_loss: 18.0884 - val_mape: 22.5339 - learning_rate: 1.0000e-04
# Epoch 36/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.6168 - mape: 21.6782 - val_loss: 18.0007 - val_mape: 22.5226 - learning_rate: 1.0000e-04
# Epoch 37/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.5818 - mape: 21.5010 - val_loss: 18.0472 - val_mape: 22.4202 - learning_rate: 1.0000e-04
# Epoch 38/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.7563 - mape: 21.5131 - val_loss: 18.1964 - val_mape: 22.3949 - learning_rate: 1.0000e-04
# Epoch 39/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6348 - mape: 21.0865 - val_loss: 18.3915 - val_mape: 22.4145 - learning_rate: 1.0000e-04
# Epoch 40/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1708 - mape: 21.0968 - val_loss: 18.1816 - val_mape: 22.4395 - learning_rate: 1.0000e-04
# Epoch 41/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.5675 - mape: 21.8741 - val_loss: 18.2599 - val_mape: 22.3255 - learning_rate: 1.0000e-04
# Epoch 42/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 19.9047 - mape: 21.9990 - val_loss: 18.2293 - val_mape: 22.3789 - learning_rate: 1.0000e-04
# Epoch 43/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.5586 - mape: 22.5237 - val_loss: 18.1640 - val_mape: 22.3816 - learning_rate: 1.0000e-04
# Epoch 44/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.5876 - mape: 21.7007 - val_loss: 18.1035 - val_mape: 22.2540 - learning_rate: 1.0000e-04
# Epoch 45/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.7673 - mape: 22.5221 - val_loss: 18.0775 - val_mape: 22.4137 - learning_rate: 1.0000e-04
# Epoch 46/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3495 - mape: 21.3004 - val_loss: 18.0310 - val_mape: 22.4211 - learning_rate: 1.0000e-04
# Epoch 47/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.8642 - mape: 21.8890 - val_loss: 18.1766 - val_mape: 22.3736 - learning_rate: 1.0000e-04
# Epoch 48/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.0266 - mape: 21.3929 - val_loss: 18.2256 - val_mape: 22.3649 - learning_rate: 1.0000e-04
# Epoch 49/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.5383 - mape: 22.1093 - val_loss: 18.1715 - val_mape: 22.2350 - learning_rate: 1.0000e-04
# Epoch 50/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 17.9547 - mape: 22.0969 - val_loss: 18.0621 - val_mape: 22.2671 - learning_rate: 5.0000e-05
# Epoch 51/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.0378 - mape: 21.4228 - val_loss: 18.0650 - val_mape: 22.2733 - learning_rate: 5.0000e-05
# Epoch 52/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2085 - mape: 21.9840 - val_loss: 18.0786 - val_mape: 22.3481 - learning_rate: 5.0000e-05
# Epoch 53/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3958 - mape: 22.6997 - val_loss: 18.1400 - val_mape: 22.3805 - learning_rate: 5.0000e-05
# Epoch 54/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.3405 - mape: 21.5066 - val_loss: 18.1459 - val_mape: 22.3156 - learning_rate: 5.0000e-05
# Epoch 55/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.7246 - mape: 21.6316 - val_loss: 18.1722 - val_mape: 22.2130 - learning_rate: 5.0000e-05
# Epoch 56/500
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.2438 - mape: 21.6864 - val_loss: 18.1579 - val_mape: 22.1800 - learning_rate: 5.0000e-05

# %%
# Saving the trained Model
model.save("python_model_Konditorei.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making Predictions and Evaluating the Model

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# MAPE on the Training Data: 20.53%
# MAPE on the Validation Data: 22.52%

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='Training MAPE')
plt.plot(history.history['val_mape'], label='Validation MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_predictions(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['actual'], label='Actual Values', color='red')
    plt.plot(data['prediction'], label='Predicted Values', color='blue')
    plt.title(title)
    plt.xlabel('Zeit')
    plt.ylabel('Umsatz')
    plt.legend()
    plt.show()

# Ensure that training_predictions, validation_predictions, training_labels, and validation_labels are numpy arrays
training_predictions = np.array(training_predictions).flatten()
validation_predictions = np.array(validation_predictions).flatten()
training_labels = np.array(training_labels).flatten()
validation_labels = np.array(validation_labels).flatten()

# print the type of the predictions
print(type(training_predictions))
print(type(validation_predictions))

# Create DataFrames with 1-dimensional arrays
data_train = pd.DataFrame({'prediction': training_predictions, 'actual': training_labels})
data_validation = pd.DataFrame({'prediction': validation_predictions, 'actual': validation_labels})

# Plot predictions
plot_predictions(data_train.head(100), 'Predicted and Actual Values for the Training Data')
plot_predictions(data_validation.head(100), 'Predicted and Actual Values for the Validation Data')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ***VORHERSAGE TESTZEITRAUM***

# %%
test_predictions = model.predict(test_features)
#print("Predictions for test data:", test_predictions[:5])  # Display first 5 predictions
# Größe des Arrays anzeigen
print("Größe des Arrays (shape):", test_predictions.shape)
test_predictions = pd.DataFrame(test_predictions)
test_predictions
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Größe des Arrays (shape): (354, 1)
#               0
# 0     84.375664
# 1     78.392670
# 2     82.533478
# 3     86.437538
# 4    122.087601
# ..          ...
# 349   76.459145
# 350   77.784920
# 351  122.038925
# 352   81.621315
# 353   79.920372
#
# [354 rows x 1 columns]

# %%
data_test = pd.read_csv("../../../0_DataPreparation/00_data/data_with_lag/Testdaten_with_lag.csv")
data_test = data_test[data_test["Warengruppe_4"] == 1]
data_test
# Out:
#            id       Datum  Warengruppe_1  Warengruppe_2  Warengruppe_3  \
# 1065  1808014  2018-08-01              0              0              0
# 1066  1808024  2018-08-02              0              0              0
# 1067  1808034  2018-08-03              0              0              0
# 1068  1808044  2018-08-04              0              0              0
# 1069  1808054  2018-08-05              0              0              0
# ...       ...         ...            ...            ...            ...
# 1414  1907264  2019-07-26              0              0              0
# 1415  1907274  2019-07-27              0              0              0
# 1416  1907284  2019-07-28              0              0              0
# 1417  1907294  2019-07-29              0              0              0
# 1418  1907304  2019-07-30              0              0              0
#
#       Warengruppe_4  Warengruppe_5  Warengruppe_6  Temp_Very_Cold_current  \
# 1065              1              0              0                       0
# 1066              1              0              0                       0
# 1067              1              0              0                       0
# 1068              1              0              0                       0
# 1069              1              0              0                       0
# ...             ...            ...            ...                     ...
# 1414              1              0              0                       0
# 1415              1              0              0                       0
# 1416              1              0              0                       0
# 1417              1              0              0                       0
# 1418              1              0              0                       0
#
#       Temp_Very_Cold_prev  ...  zwischen_den_jahren_next  \
# 1065                  0.0  ...                       0.0
# 1066                  0.0  ...                       0.0
# 1067                  0.0  ...                       0.0
# 1068                  0.0  ...                       0.0
# 1069                  0.0  ...                       0.0
# ...                   ...  ...                       ...
# 1414                  0.0  ...                       0.0
# 1415                  0.0  ...                       0.0
# 1416                  0.0  ...                       0.0
# 1417                  0.0  ...                       0.0
# 1418                  0.0  ...                       0.0
#
#       Number_of_ships_scaled_current  Number_of_ships_scaled_prev  \
# 1065                             0.0                          0.2
# 1066                             0.0                          0.0
# 1067                             0.0                          0.0
# 1068                             0.2                          0.0
# 1069                             0.0                          0.2
# ...                              ...                          ...
# 1414                             0.0                          0.2
# 1415                             0.6                          0.0
# 1416                             0.4                          0.6
# 1417                             0.2                          0.4
# 1418                             0.2                          0.2
#
#       Number_of_ships_scaled_next  Cloud_ok_current  Cloud_ok_prev  \
# 1065                          0.0                 1            0.0
# 1066                          0.0                 1            1.0
# 1067                          0.2                 1            1.0
# 1068                          0.0                 1            1.0
# 1069                          0.0                 0            1.0
# ...                           ...               ...            ...
# 1414                          0.6                 1            0.0
# 1415                          0.4                 1            1.0
# 1416                          0.2                 1            1.0
# 1417                          0.2                 0            1.0
# 1418                          0.0                 0            0.0
#
#       Cloud_ok_next  Wind_ok_current  Wind_ok_prev  Wind_ok_next
# 1065            1.0                1           1.0           1.0
# 1066            1.0                1           1.0           1.0
# 1067            1.0                1           1.0           1.0
# 1068            0.0                1           1.0           1.0
# 1069            1.0                1           1.0           1.0
# ...             ...              ...           ...           ...
# 1414            1.0                1           1.0           0.0
# 1415            1.0                0           1.0           1.0
# 1416            0.0                1           0.0           1.0
# 1417            0.0                1           1.0           1.0
# 1418            1.0                1           1.0           1.0
#
# [354 rows x 176 columns]

# %%
# Erstelle Ziel csv Datei

predictions_df = pd.DataFrame({
    'id': data_test['id'].values,
    'Umsatz': test_predictions[0].values
}).reset_index(drop=True)

# Save to a CSV file
#output_csv_path = "/workspaces/bakery_sales_prediction/3_Model/02_Franz/V3_lag/Umsatzvorhersage_Konditorei_Hochladeformat.csv"

predictions_df.to_csv('Konditorei_Umsatzvorhersage.csv', index=False)
print(f"CSV Datei erstellt")
# Out:
# CSV Datei erstellt
