# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, AdamW
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
# Out:
# Loaded Training features dimensions: (1462, 25)
# Loaded Validation features dimensions: (357, 25)
# Loaded Test features dimensions: (355, 25)
#
# Loaded Training labels dimensions: (1462, 1)
# Loaded Validation labels dimensions: (357, 1)
#
# First few rows of loaded training features:
#       Temp_Very_Cold_current  Temp_Cold_current  Temp_Mild_current  \
# 3638                       0                  0                  1
# 3639                       0                  0                  1
# 3640                       0                  0                  0
# 3641                       0                  0                  1
# 3642                       0                  0                  1
#
#       Temp_Warm_current  Temp_Hot_current  Cloud_ok_current  \
# 3638                  0                 0                 0
# 3639                  0                 0                 1
# 3640                  1                 0                 0
# 3641                  0                 0                 0
# 3642                  0                 0                 1
#
#       Cloud_Cloudy_current  KielerWoche_current  Samstag_current  \
# 3638                     1                    0                0
# 3639                     0                    0                0
# 3640                     1                    0                0
# 3641                     1                    0                0
# 3642                     0                    0                0
#
#       Sonntag_current  ...  Werktag_current  Frühling_current  Sommer_current  \
# 3638                0  ...                1                 0               1
# 3639                0  ...                1                 0               1
# 3640                0  ...                1                 0               1
# 3641                0  ...                1                 0               1
# 3642                0  ...                1                 0               1
#
#       Herbst_current  Winter_current  wetter_sehr_schlecht_current  \
# 3638               0               0                             0
# 3639               0               0                             0
# 3640               0               0                             1
# 3641               0               0                             0
# 3642               0               0                             0
#
#       wetter_sehr_schön_current  Monat_8_current  Monat_7_current  \
# 3638                          0                0                1
# 3639                          0                0                1
# 3640                          0                0                1
# 3641                          0                0                1
# 3642                          0                0                1
#
#       wetter_sehr_schön_prev
# 3638                     0.0
# 3639                     0.0
# 3640                     0.0
# 3641                     0.0
# 3642                     0.0
#
# [5 rows x 25 columns]
#
# First few rows of loaded training labels:
#           Umsatz
# 3638  201.198426
# 3639  265.261254
# 3640  210.260241
# 3641  190.686641
# 3642  181.644870

# %%
# Define the file paths
subdirectory = "pickle_data_Croissant"
training_features_path = f"{subdirectory}/training_features.pkl"
validation_features_path = f"{subdirectory}/validation_features.pkl"
test_features_path = f"{subdirectory}/test_features.pkl"
training_labels_path = f"{subdirectory}/training_labels.pkl"
validation_labels_path = f"{subdirectory}/validation_labels.pkl"
test_labels_path = f"{subdirectory}/test_labels.pkl"

# Read the pickle files
training_features = pd.read_pickle(training_features_path)
validation_features = pd.read_pickle(validation_features_path)
test_features = pd.read_pickle(test_features_path)
training_labels = pd.read_pickle(training_labels_path)
validation_labels = pd.read_pickle(validation_labels_path)
#test_labels = pd.read_pickle(test_labels_path)

# Verify the loaded data by printing their shapes and a few rows
print("Loaded Training features dimensions:", training_features.shape)
print("Loaded Validation features dimensions:", validation_features.shape)
print("Loaded Test features dimensions:", test_features.shape)
print()
print("Loaded Training labels dimensions:", training_labels.shape)
print("Loaded Validation labels dimensions:", validation_labels.shape)
#print("Loaded Test labels dimensions:", test_labels.shape)
print()

print("First few rows of loaded training features:")
print(training_features.head())
print()
print("First few rows of loaded training labels:")
print(training_labels.head())

# %%
#Defining the Neural Network
#Now, let's define our neural network. We are using a Sequential model definition from Keras with batch normalization and dense layers.

model = Sequential([
    InputLayer(shape=(training_features.shape[1], )),
    Dropout(0.1),
    Dense(50, activation='relu', kernel_initializer="he_normal"),
    Dropout(0.15),
    Dense(25, activation='relu', kernel_initializer="he_normal"),

    Dense(1)
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout_2 (Dropout)             │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 50)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,601 (10.16 KB)
#  Trainable params: 2,601 (10.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# SGD with optimized parameters
optimizer = SGD(
    #learning_rate=0.003, durch den lr_scheduler geregelt
    momentum=0.9,    # Add momentum to help escape local minima
    nesterov=True,   # Use Nesterov momentum for better convergence
)

model.compile(
    loss="huber",    # More robust to outliers
    optimizer=optimizer,
    metrics=['mape']
)

# Custom learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.003
    drop = 0.5
    epochs_drop = 50.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return max(lr, 1e-5)  # Don't let LR get too small

history = model.fit(
    training_features, 
    training_labels, 
    epochs=500,
    batch_size=16,   # Smaller batch size works better with SGD
    verbose=1,
    validation_data=(validation_features, validation_labels),
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=100,
            restore_best_weights=True,
            mode='min'
        ),
        LearningRateScheduler(lr_schedule),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_loss',
            save_best_only=True,
            mode='min'
        )
    ]
)
# Out:
# Epoch 1/500
# /home/nolnmarten/workspace/code/machinelearning/bakery_sales_prediction/.venv/lib/python3.10/site-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 115.2909 - mape: 69.5474 - val_loss: 29.5766 - val_mape: 19.2592 - learning_rate: 0.0030
# Epoch 2/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.9453 - mape: 22.6297 - val_loss: 30.2870 - val_mape: 20.9399 - learning_rate: 0.0030
# Epoch 3/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.6641 - mape: 21.9323 - val_loss: 33.2483 - val_mape: 20.3806 - learning_rate: 0.0030
# Epoch 4/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.4153 - mape: 21.4504 - val_loss: 34.2272 - val_mape: 20.9021 - learning_rate: 0.0030
# Epoch 5/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33.5703 - mape: 21.4973 - val_loss: 31.6926 - val_mape: 19.4696 - learning_rate: 0.0030
# Epoch 6/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.3304 - mape: 21.0896 - val_loss: 28.7443 - val_mape: 18.8177 - learning_rate: 0.0030
# Epoch 7/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ -1s -15032us/step - loss: 32.7468 - mape: 21.7946 - val_loss: 31.4148 - val_mape: 19.3077 - learning_rate: 0.0030
# Epoch 8/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.3386 - mape: 20.4634 - val_loss: 33.3726 - val_mape: 20.7603 - learning_rate: 0.0030
# Epoch 9/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.8319 - mape: 20.0951 - val_loss: 29.6043 - val_mape: 18.8023 - learning_rate: 0.0030
# Epoch 10/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.7953 - mape: 20.5502 - val_loss: 32.5882 - val_mape: 19.6802 - learning_rate: 0.0030
# Epoch 11/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1926 - mape: 20.0996 - val_loss: 37.1186 - val_mape: 21.6706 - learning_rate: 0.0030
# Epoch 12/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.7834 - mape: 20.4673 - val_loss: 34.3170 - val_mape: 20.1016 - learning_rate: 0.0030
# Epoch 13/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.7040 - mape: 20.0538 - val_loss: 29.7538 - val_mape: 18.5689 - learning_rate: 0.0030
# Epoch 14/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.6728 - mape: 20.0576 - val_loss: 39.6903 - val_mape: 22.5637 - learning_rate: 0.0030
# Epoch 15/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 32.2661 - mape: 20.1633 - val_loss: 30.5085 - val_mape: 19.6973 - learning_rate: 0.0030
# Epoch 16/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.0477 - mape: 20.9188 - val_loss: 30.8609 - val_mape: 20.9335 - learning_rate: 0.0030
# Epoch 17/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.9207 - mape: 20.2874 - val_loss: 30.0279 - val_mape: 18.7654 - learning_rate: 0.0030
# Epoch 18/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 30.4767 - mape: 19.6088 - val_loss: 29.9341 - val_mape: 19.0820 - learning_rate: 0.0030
# Epoch 19/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 32.5371 - mape: 20.4332 - val_loss: 34.2695 - val_mape: 20.2711 - learning_rate: 0.0030
# Epoch 20/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 30.2815 - mape: 19.5880 - val_loss: 30.6807 - val_mape: 18.8226 - learning_rate: 0.0030
# Epoch 21/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.7762 - mape: 18.8347 - val_loss: 31.7043 - val_mape: 19.2269 - learning_rate: 0.0030
# Epoch 22/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1517 - mape: 20.0019 - val_loss: 34.4744 - val_mape: 20.3768 - learning_rate: 0.0030
# Epoch 23/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.2964 - mape: 18.9459 - val_loss: 30.5988 - val_mape: 18.8206 - learning_rate: 0.0030
# Epoch 24/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0477 - mape: 19.3733 - val_loss: 29.2282 - val_mape: 18.5518 - learning_rate: 0.0030
# Epoch 25/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.4946 - mape: 20.1944 - val_loss: 31.1602 - val_mape: 18.5172 - learning_rate: 0.0030
# Epoch 26/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.5098 - mape: 19.4917 - val_loss: 30.8864 - val_mape: 19.2015 - learning_rate: 0.0030
# Epoch 27/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.0467 - mape: 20.6354 - val_loss: 30.5915 - val_mape: 18.8052 - learning_rate: 0.0030
# Epoch 28/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.2856 - mape: 20.1448 - val_loss: 27.5401 - val_mape: 17.5541 - learning_rate: 0.0030
# Epoch 29/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8973 - mape: 19.7779 - val_loss: 30.4204 - val_mape: 19.0968 - learning_rate: 0.0030
# Epoch 30/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.4424 - mape: 19.2921 - val_loss: 30.6316 - val_mape: 20.1732 - learning_rate: 0.0030
# Epoch 31/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.4231 - mape: 20.3279 - val_loss: 30.9938 - val_mape: 18.7905 - learning_rate: 0.0030
# Epoch 32/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.9570 - mape: 19.8245 - val_loss: 29.5810 - val_mape: 18.6814 - learning_rate: 0.0030
# Epoch 33/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8203 - mape: 18.8335 - val_loss: 31.8383 - val_mape: 19.0020 - learning_rate: 0.0030
# Epoch 34/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.4952 - mape: 19.4522 - val_loss: 33.6089 - val_mape: 19.6512 - learning_rate: 0.0030
# Epoch 35/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.6523 - mape: 18.8477 - val_loss: 32.6171 - val_mape: 18.9016 - learning_rate: 0.0030
# Epoch 36/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.1174 - mape: 19.6873 - val_loss: 30.0299 - val_mape: 20.1946 - learning_rate: 0.0030
# Epoch 37/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.8464 - mape: 20.6670 - val_loss: 33.2889 - val_mape: 19.3671 - learning_rate: 0.0030
# Epoch 38/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1758 - mape: 19.7425 - val_loss: 29.5307 - val_mape: 18.7903 - learning_rate: 0.0030
# Epoch 39/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.2033 - mape: 19.4969 - val_loss: 30.2962 - val_mape: 19.7040 - learning_rate: 0.0030
# Epoch 40/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.9267 - mape: 19.1644 - val_loss: 28.8278 - val_mape: 18.4807 - learning_rate: 0.0030
# Epoch 41/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8939 - mape: 18.7800 - val_loss: 32.4776 - val_mape: 19.1248 - learning_rate: 0.0030
# Epoch 42/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.7960 - mape: 19.3586 - val_loss: 30.8228 - val_mape: 19.1119 - learning_rate: 0.0030
# Epoch 43/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.9380 - mape: 18.8182 - val_loss: 29.2253 - val_mape: 18.5106 - learning_rate: 0.0030
# Epoch 44/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.6658 - mape: 19.5555 - val_loss: 30.2196 - val_mape: 18.7770 - learning_rate: 0.0030
# Epoch 45/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.4105 - mape: 18.8140 - val_loss: 33.4101 - val_mape: 19.3249 - learning_rate: 0.0030
# Epoch 46/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.3686 - mape: 19.9142 - val_loss: 33.9622 - val_mape: 19.9458 - learning_rate: 0.0030
# Epoch 47/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.3386 - mape: 19.1875 - val_loss: 28.8214 - val_mape: 18.5710 - learning_rate: 0.0030
# Epoch 48/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8196 - mape: 18.9273 - val_loss: 31.6183 - val_mape: 19.0842 - learning_rate: 0.0030
# Epoch 49/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.7445 - mape: 19.1531 - val_loss: 28.8624 - val_mape: 18.3950 - learning_rate: 0.0030
# Epoch 50/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1329 - mape: 19.1882 - val_loss: 29.5969 - val_mape: 18.8964 - learning_rate: 0.0015
# Epoch 51/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.9209 - mape: 18.8634 - val_loss: 31.3097 - val_mape: 19.3153 - learning_rate: 0.0015
# Epoch 52/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.7958 - mape: 19.2675 - val_loss: 31.2423 - val_mape: 18.8468 - learning_rate: 0.0015
# Epoch 53/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0581 - mape: 19.2681 - val_loss: 28.7168 - val_mape: 18.9857 - learning_rate: 0.0015
# Epoch 54/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.1663 - mape: 19.4474 - val_loss: 30.1023 - val_mape: 18.6793 - learning_rate: 0.0015
# Epoch 55/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.3689 - mape: 18.0964 - val_loss: 29.3965 - val_mape: 18.3103 - learning_rate: 0.0015
# Epoch 56/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.6956 - mape: 17.6358 - val_loss: 29.2108 - val_mape: 19.0061 - learning_rate: 0.0015
# Epoch 57/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.2111 - mape: 18.4175 - val_loss: 31.3916 - val_mape: 19.0138 - learning_rate: 0.0015
# Epoch 58/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.5399 - mape: 18.3034 - val_loss: 30.0143 - val_mape: 18.6040 - learning_rate: 0.0015
# Epoch 59/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.9196 - mape: 18.3681 - val_loss: 30.3384 - val_mape: 18.5227 - learning_rate: 0.0015
# Epoch 60/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.8356 - mape: 18.4669 - val_loss: 31.6604 - val_mape: 19.0204 - learning_rate: 0.0015
# Epoch 61/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.6543 - mape: 18.5403 - val_loss: 29.5348 - val_mape: 18.2489 - learning_rate: 0.0015
# Epoch 62/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.7633 - mape: 18.1863 - val_loss: 29.8302 - val_mape: 18.5400 - learning_rate: 0.0015
# Epoch 63/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.0747 - mape: 18.9849 - val_loss: 29.0411 - val_mape: 18.4580 - learning_rate: 0.0015
# Epoch 64/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.6738 - mape: 18.1004 - val_loss: 31.6293 - val_mape: 19.0015 - learning_rate: 0.0015
# Epoch 65/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.0914 - mape: 18.1586 - val_loss: 29.3860 - val_mape: 18.3892 - learning_rate: 0.0015
# Epoch 66/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28.5446 - mape: 18.4168 - val_loss: 30.9149 - val_mape: 18.8039 - learning_rate: 0.0015
# Epoch 67/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.7026 - mape: 18.5515 - val_loss: 30.9993 - val_mape: 18.9355 - learning_rate: 0.0015
# Epoch 68/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.1940 - mape: 19.0604 - val_loss: 30.3992 - val_mape: 19.0605 - learning_rate: 0.0015
# Epoch 69/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.3381 - mape: 19.8407 - val_loss: 32.5269 - val_mape: 19.3854 - learning_rate: 0.0015
# Epoch 70/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.2131 - mape: 18.7442 - val_loss: 31.0907 - val_mape: 18.9933 - learning_rate: 0.0015
# Epoch 71/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28.1753 - mape: 18.6554 - val_loss: 32.0033 - val_mape: 18.9710 - learning_rate: 0.0015
# Epoch 72/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 29.5472 - mape: 18.7258 - val_loss: 30.7971 - val_mape: 19.1783 - learning_rate: 0.0015
# Epoch 73/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.8693 - mape: 18.0402 - val_loss: 29.2427 - val_mape: 18.8755 - learning_rate: 0.0015
# Epoch 74/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.7653 - mape: 18.6292 - val_loss: 32.5700 - val_mape: 19.3297 - learning_rate: 0.0015
# Epoch 75/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.6150 - mape: 18.1211 - val_loss: 30.6400 - val_mape: 18.8451 - learning_rate: 0.0015
# Epoch 76/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1431 - mape: 18.2881 - val_loss: 29.8291 - val_mape: 18.8915 - learning_rate: 0.0015
# Epoch 77/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.3699 - mape: 18.2207 - val_loss: 30.1046 - val_mape: 19.3409 - learning_rate: 0.0015
# Epoch 78/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.4580 - mape: 17.8599 - val_loss: 30.5588 - val_mape: 18.8827 - learning_rate: 0.0015
# Epoch 79/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.2949 - mape: 19.2673 - val_loss: 29.3266 - val_mape: 18.6799 - learning_rate: 0.0015
# Epoch 80/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ -1s -14100us/step - loss: 29.6067 - mape: 19.0599 - val_loss: 31.1308 - val_mape: 18.9594 - learning_rate: 0.0015
# Epoch 81/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 29.9256 - mape: 18.8239 - val_loss: 30.2222 - val_mape: 18.8718 - learning_rate: 0.0015
# Epoch 82/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.6667 - mape: 19.3044 - val_loss: 29.8383 - val_mape: 18.7970 - learning_rate: 0.0015
# Epoch 83/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.6271 - mape: 18.6611 - val_loss: 30.6431 - val_mape: 18.8850 - learning_rate: 0.0015
# Epoch 84/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8201 - mape: 18.8072 - val_loss: 29.9241 - val_mape: 18.6985 - learning_rate: 0.0015
# Epoch 85/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.0091 - mape: 18.4273 - val_loss: 31.4488 - val_mape: 19.3352 - learning_rate: 0.0015
# Epoch 86/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.0563 - mape: 19.0946 - val_loss: 29.6369 - val_mape: 19.1033 - learning_rate: 0.0015
# Epoch 87/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.3158 - mape: 19.0695 - val_loss: 30.4914 - val_mape: 19.0149 - learning_rate: 0.0015
# Epoch 88/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.1074 - mape: 18.5241 - val_loss: 30.8833 - val_mape: 19.6637 - learning_rate: 0.0015
# Epoch 89/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.2961 - mape: 19.2770 - val_loss: 30.8791 - val_mape: 19.1959 - learning_rate: 0.0015
# Epoch 90/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.4410 - mape: 18.6213 - val_loss: 31.8241 - val_mape: 18.9663 - learning_rate: 0.0015
# Epoch 91/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.9592 - mape: 18.7895 - val_loss: 30.5842 - val_mape: 19.3523 - learning_rate: 0.0015
# Epoch 92/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 27.8685 - mape: 18.4129 - val_loss: 29.7596 - val_mape: 19.1197 - learning_rate: 0.0015
# Epoch 93/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.5184 - mape: 18.4469 - val_loss: 31.6404 - val_mape: 19.1737 - learning_rate: 0.0015
# Epoch 94/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.2952 - mape: 18.3429 - val_loss: 30.6062 - val_mape: 19.0006 - learning_rate: 0.0015
# Epoch 95/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.7305 - mape: 17.6887 - val_loss: 29.6362 - val_mape: 19.0865 - learning_rate: 0.0015
# Epoch 96/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.3326 - mape: 18.1014 - val_loss: 29.6985 - val_mape: 19.6301 - learning_rate: 0.0015
# Epoch 97/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0534 - mape: 20.1610 - val_loss: 31.1539 - val_mape: 19.0968 - learning_rate: 0.0015
# Epoch 98/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.7002 - mape: 18.8378 - val_loss: 32.9311 - val_mape: 19.8330 - learning_rate: 0.0015
# Epoch 99/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.1080 - mape: 18.9189 - val_loss: 30.8562 - val_mape: 19.5561 - learning_rate: 0.0015
# Epoch 100/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 28.5155 - mape: 19.2732 - val_loss: 32.0000 - val_mape: 19.2238 - learning_rate: 7.5000e-04
# Epoch 101/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 26.2648 - mape: 17.2029 - val_loss: 33.7975 - val_mape: 19.7645 - learning_rate: 7.5000e-04
# Epoch 102/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.1918 - mape: 18.0478 - val_loss: 30.9626 - val_mape: 19.0564 - learning_rate: 7.5000e-04
# Epoch 103/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.6625 - mape: 17.9091 - val_loss: 31.0415 - val_mape: 18.9037 - learning_rate: 7.5000e-04
# Epoch 104/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 29.1609 - mape: 18.4582 - val_loss: 29.8356 - val_mape: 18.9029 - learning_rate: 7.5000e-04
# Epoch 105/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.1142 - mape: 17.7563 - val_loss: 31.2198 - val_mape: 18.9024 - learning_rate: 7.5000e-04
# Epoch 106/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.0841 - mape: 18.0758 - val_loss: 28.9275 - val_mape: 18.7029 - learning_rate: 7.5000e-04
# Epoch 107/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 26.6875 - mape: 18.4388 - val_loss: 30.2207 - val_mape: 18.7693 - learning_rate: 7.5000e-04
# Epoch 108/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.4613 - mape: 18.0884 - val_loss: 29.6700 - val_mape: 18.5657 - learning_rate: 7.5000e-04
# Epoch 109/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 27.9419 - mape: 18.2238 - val_loss: 30.9226 - val_mape: 18.6976 - learning_rate: 7.5000e-04
# Epoch 110/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.7280 - mape: 18.2933 - val_loss: 29.2670 - val_mape: 18.7146 - learning_rate: 7.5000e-04
# Epoch 111/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 26.5109 - mape: 17.6913 - val_loss: 30.3795 - val_mape: 18.8360 - learning_rate: 7.5000e-04
# Epoch 112/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.6404 - mape: 17.9594 - val_loss: 30.2677 - val_mape: 19.0288 - learning_rate: 7.5000e-04
# Epoch 113/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.4773 - mape: 17.9528 - val_loss: 29.5423 - val_mape: 18.5424 - learning_rate: 7.5000e-04
# Epoch 114/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 27.8805 - mape: 17.7948 - val_loss: 32.6468 - val_mape: 19.4762 - learning_rate: 7.5000e-04
# Epoch 115/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 28.9383 - mape: 17.7417 - val_loss: 29.6199 - val_mape: 18.6400 - learning_rate: 7.5000e-04
# Epoch 116/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.0728 - mape: 17.2537 - val_loss: 29.6120 - val_mape: 19.0480 - learning_rate: 7.5000e-04
# Epoch 117/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.3028 - mape: 17.9726 - val_loss: 30.8878 - val_mape: 18.8558 - learning_rate: 7.5000e-04
# Epoch 118/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.9715 - mape: 17.6082 - val_loss: 30.9652 - val_mape: 18.7851 - learning_rate: 7.5000e-04
# Epoch 119/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 26.1076 - mape: 17.3336 - val_loss: 31.1492 - val_mape: 19.0779 - learning_rate: 7.5000e-04
# Epoch 120/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 28.0526 - mape: 18.2319 - val_loss: 30.4790 - val_mape: 18.7074 - learning_rate: 7.5000e-04
# Epoch 121/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.8540 - mape: 18.2285 - val_loss: 30.3222 - val_mape: 18.8675 - learning_rate: 7.5000e-04
# Epoch 122/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.7567 - mape: 17.7615 - val_loss: 30.5291 - val_mape: 18.9796 - learning_rate: 7.5000e-04
# Epoch 123/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 26.5549 - mape: 18.1198 - val_loss: 30.4211 - val_mape: 18.7006 - learning_rate: 7.5000e-04
# Epoch 124/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.0476 - mape: 18.6105 - val_loss: 30.2572 - val_mape: 18.8394 - learning_rate: 7.5000e-04
# Epoch 125/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 27.8937 - mape: 18.2065 - val_loss: 31.1833 - val_mape: 18.9388 - learning_rate: 7.5000e-04
# Epoch 126/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 28.1307 - mape: 18.8142 - val_loss: 30.2500 - val_mape: 19.1368 - learning_rate: 7.5000e-04
# Epoch 127/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 27.2742 - mape: 18.0245 - val_loss: 29.5735 - val_mape: 18.8381 - learning_rate: 7.5000e-04
# Epoch 128/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.8786 - mape: 19.0263 - val_loss: 30.7138 - val_mape: 18.7466 - learning_rate: 7.5000e-04

# %%
# Saving the trained Model
model.save("python_model_Croissant.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making Predictions and Evaluating the Model
def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# MAPE on the Training Data: 17.42%
# MAPE on the Validation Data: 17.55%

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mape'], label='Training MAPE')
plt.plot(history.history['val_mape'], label='Validation MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_predictions(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['actual'], label='Actual Values', color='red')
    plt.plot(data['prediction'], label='Predicted Values', color='blue')
    plt.title(title)
    plt.xlabel('Zeit')
    plt.ylabel('Umsatz')
    plt.legend()
    plt.show()

# Ensure that training_predictions, validation_predictions, training_labels, and validation_labels are numpy arrays
training_predictions = np.array(training_predictions).flatten()
validation_predictions = np.array(validation_predictions).flatten()
training_labels = np.array(training_labels).flatten()
validation_labels = np.array(validation_labels).flatten()

# print the type of the predictions
print(type(training_predictions))
print(type(validation_predictions))

# Create DataFrames with 1-dimensional arrays
data_train = pd.DataFrame({'prediction': training_predictions, 'actual': training_labels})
data_validation = pd.DataFrame({'prediction': validation_predictions, 'actual': validation_labels})

# Plot predictions
plot_predictions(data_train.head(100), 'Predicted and Actual Values for the Training Data')
plot_predictions(data_validation.head(100), 'Predicted and Actual Values for the Validation Data')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ***VORHERSAGE TESTZEITRAUM***

# %%
test_predictions = model.predict(test_features)
#print("Predictions for test data:", test_predictions[:5])  # Display first 5 predictions
# Größe des Arrays anzeigen
print("Größe des Arrays (shape):", test_predictions.shape)
test_predictions = pd.DataFrame(test_predictions)
test_predictions
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ -2s -153104us/step
# Größe des Arrays (shape): (355, 1)
#               0
# 0    265.371948
# 1    279.356720
# 2    279.356720
# 3    328.897339
# 4    297.760071
# ..          ...
# 350  265.046326
# 351  308.097412
# 352  305.291260
# 353  237.023239
# 354  240.811981
#
# [355 rows x 1 columns]

# %%
data_test = pd.read_csv("../../../0_DataPreparation/00_data/data_with_lag/Testdaten_with_lag.csv")
data_test = data_test[data_test["Warengruppe_3"] == 1]
data_test
# Out:
#            id       Datum  Warengruppe_1  Warengruppe_2  Warengruppe_3  \
# 710   1808013  2018-08-01              0              0              1
# 711   1808023  2018-08-02              0              0              1
# 712   1808033  2018-08-03              0              0              1
# 713   1808043  2018-08-04              0              0              1
# 714   1808053  2018-08-05              0              0              1
# ...       ...         ...            ...            ...            ...
# 1060  1907263  2019-07-26              0              0              1
# 1061  1907273  2019-07-27              0              0              1
# 1062  1907283  2019-07-28              0              0              1
# 1063  1907293  2019-07-29              0              0              1
# 1064  1907303  2019-07-30              0              0              1
#
#       Warengruppe_4  Warengruppe_5  Warengruppe_6  Temp_Very_Cold_current  \
# 710               0              0              0                       0
# 711               0              0              0                       0
# 712               0              0              0                       0
# 713               0              0              0                       0
# 714               0              0              0                       0
# ...             ...            ...            ...                     ...
# 1060              0              0              0                       0
# 1061              0              0              0                       0
# 1062              0              0              0                       0
# 1063              0              0              0                       0
# 1064              0              0              0                       0
#
#       Temp_Very_Cold_prev  ...  zwischen_den_jahren_next  \
# 710                   0.0  ...                       0.0
# 711                   0.0  ...                       0.0
# 712                   0.0  ...                       0.0
# 713                   0.0  ...                       0.0
# 714                   0.0  ...                       0.0
# ...                   ...  ...                       ...
# 1060                  0.0  ...                       0.0
# 1061                  0.0  ...                       0.0
# 1062                  0.0  ...                       0.0
# 1063                  0.0  ...                       0.0
# 1064                  0.0  ...                       0.0
#
#       Number_of_ships_scaled_current  Number_of_ships_scaled_prev  \
# 710                              0.0                          0.2
# 711                              0.0                          0.0
# 712                              0.0                          0.0
# 713                              0.2                          0.0
# 714                              0.0                          0.2
# ...                              ...                          ...
# 1060                             0.0                          0.2
# 1061                             0.6                          0.0
# 1062                             0.4                          0.6
# 1063                             0.2                          0.4
# 1064                             0.2                          0.2
#
#       Number_of_ships_scaled_next  Cloud_ok_current  Cloud_ok_prev  \
# 710                           0.0                 1            0.0
# 711                           0.0                 1            1.0
# 712                           0.2                 1            1.0
# 713                           0.0                 1            1.0
# 714                           0.0                 0            1.0
# ...                           ...               ...            ...
# 1060                          0.6                 1            0.0
# 1061                          0.4                 1            1.0
# 1062                          0.2                 1            1.0
# 1063                          0.2                 0            1.0
# 1064                          0.0                 0            0.0
#
#       Cloud_ok_next  Wind_ok_current  Wind_ok_prev  Wind_ok_next
# 710             1.0                1           1.0           1.0
# 711             1.0                1           1.0           1.0
# 712             1.0                1           1.0           1.0
# 713             0.0                1           1.0           1.0
# 714             1.0                1           1.0           1.0
# ...             ...              ...           ...           ...
# 1060            1.0                1           1.0           0.0
# 1061            1.0                0           1.0           1.0
# 1062            0.0                1           0.0           1.0
# 1063            0.0                1           1.0           1.0
# 1064            1.0                1           1.0           1.0
#
# [355 rows x 176 columns]

# %%
# Erstelle Ziel csv Datei

predictions_df = pd.DataFrame({
    'id': data_test['id'].values,
    'Umsatz': test_predictions[0].values
}).reset_index(drop=True)

# Save to a CSV file
#output_csv_path = "/workspaces/bakery_sales_prediction/3_Model/02_Franz/V3_lag/Umsatzvorhersage_Croissant_Hochladeformat.csv"

predictions_df.to_csv('Croissant_Umsatzvorhersage.csv', index=False)
print(f"CSV Datei erstellt")
# Out:
# CSV Datei erstellt
