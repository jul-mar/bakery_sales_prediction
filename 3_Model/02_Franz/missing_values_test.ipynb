# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from fancyimpute import IterativeImputer, KNN

# %%
data = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/00_data/data_long.csv")
# Matrix plot of missing data
msno.matrix(data, figsize=(12, 6))
plt.title('Missing Data Matrix Plot')
plt.show()
print("Dimensionen des DataFrames:", data.shape)
# Out:
# Dimensionen des DataFrames: (9334, 40)

# %%
dataw = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/07_Wetter/wetter.csv")
print("Dimensionen des DataFrames:", dataw.shape)
# Out:
# Dimensionen des DataFrames: (2601, 5)
