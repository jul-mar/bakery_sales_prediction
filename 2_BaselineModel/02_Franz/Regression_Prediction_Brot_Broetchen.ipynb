# %%
import pandas as pd  # For data manipulation and handling
import statsmodels.formula.api as smf  # For statistical modeling
import statsmodels.api as sm  # Building and summarizing regression models
from sklearn.preprocessing import StandardScaler  # Scaling features for regression
from sklearn.model_selection import train_test_split  # Splitting data into train and test sets
import matplotlib.pyplot as plt  # Visualization library
import seaborn as sns  # Advanced data visualizations

data_train = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/Trainingsdaten.csv")
data_vali = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/Validierungsdaten.csv")

# -------- Vorhersage für Brötchen für den Validierungszeitraum in Abhängigkeit von Weihnachtsmarkt ---------

# Select features and target variable
features = ['Weihnachtsmarkt']
X_train = data_train[features]
y_train = data_train['Broetchen']
X_vali = data_vali[features]
y_vali = data_vali['Broetchen']

# Scale the feature data to standardize the range (notwendig wegen unterschiedlicher Einheiten)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Add a constant term to the training data for the regression intercept
X_train = sm.add_constant(X_train)

# Train the linear regression model using Statsmodels
model = sm.OLS(y_train, X_train).fit()

# Print the summary of the regression model
print(model.summary())

# Make predictions on the test set
X_vali = sm.add_constant(X_vali)  # Add constant to test set for predictions
predictions = model.predict(X_vali)
print("\n- - - - - Predictions for test data: - - - - -\n", predictions)

# das hier zeigt alle Daten an
print(predictions.to_string())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Broetchen   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     70.49
# Date:                Fri, 06 Dec 2024   Prob (F-statistic):           1.08e-16
# Time:                        13:41:01   Log-Likelihood:                -9279.3
# No. Observations:                1462   AIC:                         1.856e+04
# Df Residuals:                    1460   BIC:                         1.857e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             419.7514      3.776    111.177      0.000     412.345     427.157
# Weihnachtsmarkt  -109.7357     13.070     -8.396      0.000    -135.373     -84.098
# ==============================================================================
# Omnibus:                      145.251   Durbin-Watson:                   0.605
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.097
# Skew:                           0.832   Prob(JB):                     8.67e-42
# Kurtosis:                       3.576   Cond. No.                         3.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# - - - - - Predictions for test data: - - - - -
#  0      419.751435
# 1      419.751435
# 2      419.751435
# 3      419.751435
# 4      419.751435
#           ...
# 352    419.751435
# 353    419.751435
# 354    419.751435
# 355    419.751435
# 356    419.751435
# Length: 357, dtype: float64
# 0      419.751435
# 1      419.751435
# 2      419.751435
# 3      419.751435
# 4      419.751435
# 5      419.751435
# 6      419.751435
# 7      419.751435
# 8      419.751435
# 9      419.751435
# 10     419.751435
# 11     419.751435
# 12     419.751435
# 13     419.751435
# 14     419.751435
# 15     419.751435
# 16     419.751435
# 17     419.751435
# 18     419.751435
# 19     419.751435
# 20     419.751435
# 21     419.751435
# 22     419.751435
# 23     419.751435
# 24     419.751435
# 25     419.751435
# 26     419.751435
# 27     419.751435
# 28     419.751435
# 29     419.751435
# 30     419.751435
# 31     419.751435
# 32     419.751435
# 33     419.751435
# 34     419.751435
# 35     419.751435
# 36     419.751435
# 37     419.751435
# 38     419.751435
import pandas as pd  # For data manipulation and handling
import statsmodels.formula.api as smf  # For statistical modeling
import statsmodels.api as sm  # Building and summarizing regression models
from sklearn.preprocessing import StandardScaler  # Scaling features for regression
from sklearn.model_selection import train_test_split  # Splitting data into train and test sets
import matplotlib.pyplot as plt  # Visualization library
import seaborn as sns  # Advanced data visualizations

data_train = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/Trainingsdaten.csv")
data_vali = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/Validierungsdaten.csv")

# -------- Vorhersage für Brot für den Validierungszeitraum in Abhängigkeit von Sonntag ---------

# Select features and target variable
features = ['Sonntag']
X_train = data_train[features]
y_train = data_train['Brot']
X_vali = data_vali[features]
y_vali = data_vali['Brot']

# Scale the feature data to standardize the range (notwendig wegen unterschiedlicher Einheiten)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Add a constant term to the training data for the regression intercept
X_train = sm.add_constant(X_train)

# Train the linear regression model using Statsmodels
model = sm.OLS(y_train, X_train).fit()

# Print the summary of the regression model
print(model.summary())

# Make predictions on the test set
X_vali = sm.add_constant(X_vali)  # Add constant to test set for predictions
predictions = model.predict(X_vali)
print("\n- - - - - Predictions for test data: - - - - -\n", predictions)

# das hier zeigt alle Daten an
print(predictions.to_string())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Brot   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     471.5
# Date:                Fri, 06 Dec 2024   Prob (F-statistic):           7.92e-91
# Time:                        15:31:47   Log-Likelihood:                -7252.9
# No. Observations:                1462   AIC:                         1.451e+04
# Df Residuals:                    1460   BIC:                         1.452e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        129.3286      0.976    132.516      0.000     127.414     131.243
# Sonntag      -56.1836      2.587    -21.714      0.000     -61.259     -51.108
# ==============================================================================
# Omnibus:                      479.680   Durbin-Watson:                   1.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2711.662
# Skew:                           1.415   Prob(JB):                         0.00
# Kurtosis:                       9.042   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# - - - - - Predictions for test data: - - - - -
#  0      129.328617
# 1      129.328617
# 2      129.328617
# 3      129.328617
# 4      129.328617
#           ...
# 352    129.328617
# 353    129.328617
# 354     73.144978
# 355    129.328617
# 356    129.328617
# Length: 357, dtype: float64
# 0      129.328617
# 1      129.328617
# 2      129.328617
# 3      129.328617
# 4      129.328617
# 5       73.144978
# 6      129.328617
# 7      129.328617
# 8      129.328617
# 9      129.328617
# 10     129.328617
# 11     129.328617
# 12      73.144978
# 13     129.328617
# 14     129.328617
# 15     129.328617
# 16     129.328617
# 17     129.328617
# 18     129.328617
# 19      73.144978
# 20     129.328617
# 21     129.328617
# 22     129.328617
# 23     129.328617
# 24     129.328617
# 25     129.328617
# 26      73.144978
# 27     129.328617
# 28     129.328617
# 29     129.328617
# 30     129.328617
# 31     129.328617
# 32     129.328617
# 33      73.144978
# 34     129.328617
# 35     129.328617
# 36     129.328617
# 37     129.328617
