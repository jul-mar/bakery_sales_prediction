# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/data.csv")
data
# Out:
#            Datum        Brot   Broetchen   Croissant  Konditorei      Kuchen  \
# 0     2013-07-01  148.828353  535.856285  201.198426   65.890169  317.475875
# 1     2013-07-02  159.793757  546.780787  265.261254   74.543917  383.628682
# 2     2013-07-03  111.885594  427.343259  210.260241   69.262728  305.523072
# 3     2013-07-04  168.864941  454.859641  190.686641   61.490175  308.408168
# 4     2013-07-05  171.280754  492.818804  181.644870   86.759861  355.518770
# ...          ...         ...         ...         ...         ...         ...
# 1814  2018-07-27  198.225523  677.415844  333.774099   65.563734  297.867853
# 1815  2018-07-28  214.470393  716.576825  371.819770   54.047422  290.024007
# 1816  2018-07-29  129.801991  721.822447  433.820697  128.952852  335.823557
# 1817  2018-07-30  148.541340  616.358562  348.770346   71.822977  324.965348
# 1818  2018-07-31  123.075682  586.081666  285.872616   57.102795  261.341313
#
# ...

# %%
model = smf.ols("Umsatz_total ~ VPI", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Umsatz_total   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     4.517
# Date:                Sun, 01 Dec 2024   Prob (F-statistic):             0.0337
# Time:                        21:18:38   Log-Likelihood:                -12893.
# No. Observations:                1819   AIC:                         2.579e+04
# Df Residuals:                    1817   BIC:                         2.580e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2055.1861    468.120      4.390      0.000    1137.076    2973.296
# ...

# %%
model = smf.ols("Umsatz_total ~ Temp_Very_Cold + Temp_Cold + Temp_Mild + Temp_Warm + Temp_Hot + Cloud_Clear + Cloud_Partly_Cloudy + Cloud_Cloudy + Wind_Light + Wind_Moderate + Wind_Strong + Weather_Good + Weather_Light_Issues + Weather_Moderate + Weather_Severe + Weather_Unknown + KielerWoche + VPI", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Umsatz_total   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     35.80
# Date:                Sun, 01 Dec 2024   Prob (F-statistic):           5.83e-91
# Time:                        21:19:41   Log-Likelihood:                -12638.
# No. Observations:                1816   AIC:                         2.531e+04
# Df Residuals:                    1800   BIC:                         2.540e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             2212.6150    264.240      8.374      0.000    1694.367    2730.864
# ...

# %%
# Ab hier versuch der Implementierung mit der Bibliothek scikit-learn

# %%
X1 = data["Brot"]
X2 = data["KielerWoche"]
X3 = data["Temperatur"]
X4 = data["VPI"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperatur'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 3
#       1 X1 = data["Brot"]
#       2 X2 = data["KielerWoche"]
# ...

# %%
X = np.hstack([X2, X1])

# %%
y = data["Umsatz_total"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
# ...

# %%
# Skalierung der Prädiktorvariablen
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 3
#       1 # Skalierung der Prädiktorvariablen
#       2 scaler = StandardScaler()
# ----> 3 X_train_scaled = scaler.fit_transform(X_train)
#       4 X_test_scaled = scaler.transform(X_test)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 model = LinearRegression()
# ----> 2 model.fit(X_train, y_train)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/linear_model/_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
# ...
