# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("/workspaces/bakery_sales_prediction/0_DataPreparation/data.csv")
data
# Out:
#       Unnamed: 0       Datum        Brot   Broetchen   Crossaint  Konditorei  \
# 0              0  2013-07-01  148.828353  535.856285  201.198426   65.890169
# 1              1  2013-07-02  159.793757  546.780787  265.261254   74.543917
# 2              2  2013-07-03  111.885594  427.343259  210.260241   69.262728
# 3              3  2013-07-04  168.864941  454.859641  190.686641   61.490175
# 4              4  2013-07-05  171.280754  492.818804  181.644870   86.759861
# ...          ...         ...         ...         ...         ...         ...
# 1947        1947  2018-07-30  148.541340  616.358562  348.770346   71.822977
# 1948        1948  2018-07-30  148.541340  616.358562  348.770346   71.822977
# 1949        1949  2018-07-30  148.541340  616.358562  348.770346   71.822977
# 1950        1950  2018-07-31  123.075682  586.081666  285.872616   57.102795
# 1951        1951  2018-07-31  123.075682  586.081666  285.872616   57.102795
#
# ...

# %%
model = smf.ols("Umsatz_total ~ Temperatur", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Umsatz_total   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     627.2
# Date:                Thu, 28 Nov 2024   Prob (F-statistic):          3.16e-120
# Time:                        16:12:45   Log-Likelihood:                -13588.
# No. Observations:                1949   AIC:                         2.718e+04
# Df Residuals:                    1947   BIC:                         2.719e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    824.1360     11.565     71.261      0.000     801.455     846.817
# ...

# %%
model = smf.ols("Umsatz_total ~ Temperatur + Windgeschwindigkeit + KielerWoche + VPI", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Umsatz_total   R-squared:                       0.272
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     181.5
# Date:                Thu, 28 Nov 2024   Prob (F-statistic):          2.82e-132
# Time:                        16:15:09   Log-Likelihood:                -13551.
# No. Observations:                1949   AIC:                         2.711e+04
# Df Residuals:                    1944   BIC:                         2.714e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            3569.1774    388.287      9.192      0.000    2807.674    4330.681
# ...

# %%
X1 = data["Datum"]
X2 = data["KielerWoche"]
X3 = data["Temperatur"]
X4 = data["VPI"]

# %%
X = np.hstack([X1, X2, X3, X4])

# %%
y = data["Umsatz_total"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# NameError: name 'y' is not defined
